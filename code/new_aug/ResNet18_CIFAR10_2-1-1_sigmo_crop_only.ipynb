# %% [markdown]
# <a href="https://colab.research.google.com/github/ndb796/Deep-Learning-Paper-Review-and-Practice/blob/master/code_practices/ResNet18_CIFAR10_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
import torch
import random
import torch.backends.cudnn as cudnn

torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)
cudnn.benchmark = False
cudnn.deterministic = True
random.seed(0)

# %% [markdown]
# #### ResNet18 모델 정의 및 인스턴스 초기화

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os


# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)  # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)  # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential()  # identity인 경우
        if stride != 1:  # stride가 1이 아니라면, Identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.sigmoid(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)  # (핵심) skip connection
        out = F.sigmoid(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes  # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.sigmoid(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# #### 데이터셋(Dataset) 다운로드 및 불러오기

# %%
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import ConcatDataset

data_transformations = {
    "basic": transforms.Compose([
        transforms.ToTensor()
    ]),
    "crop_flip": transforms.Compose([  # 크롭 + 뒤집기
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor()
    ])
}

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=data_transformations["basic"])
train_aug_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=data_transformations["crop_flip"])
augmented_train_data = ConcatDataset((train_dataset, train_aug_dataset))

test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=data_transformations["basic"])

train_loader = torch.utils.data.DataLoader(augmented_train_data, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# #### 환경 설정 및 학습(Training) 함수 정의

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.1
file_name = 'resnet18_cifar10.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 50:
        lr = 0.01
    if epoch >= 75:
        lr = 0.001
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# #### 학습(Training) 진행

# %% [markdown]
# * 대략 20번의 epoch 이후에도 85%가량의 test accuracy를 얻을 수 있습니다.

# %%
# for epoch in range(0, 200):
for epoch in range(0, 100):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current benign train accuracy: 0.109375
# Current benign train loss: 2.307521104812622
#
# Current batch: 100
# Current benign train accuracy: 0.234375
# Current benign train loss: 3.6166040897369385
#
# Current batch: 200
# Current benign train accuracy: 0.21875
# Current benign train loss: 2.003049850463867
#
# Current batch: 300
# Current benign train accuracy: 0.25
# Current benign train loss: 2.124253511428833
#
# Current batch: 400
# Current benign train accuracy: 0.2890625
# Current benign train loss: 2.214184522628784
#
# Current batch: 500
# Current benign train accuracy: 0.2890625
# Current benign train loss: 1.880517840385437
#
# Current batch: 600
# Current benign train accuracy: 0.359375
# Current benign train loss: 1.752357006072998
#
# Current batch: 700
# Current benign train accuracy: 0.25
# Current benign train loss: 2.1732265949249268
#
# Total benign train accuarcy: 26.453
# Total benign train loss: 1962.9975199699402
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 21.95
# Test average loss: 0.026226836133003233
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.2890625
# Current benign train loss: 1.8886299133300781
#
# Current batch: 100
# Current benign train accuracy: 0.390625
# Current benign train loss: 1.8204573392868042
#
# Current batch: 200
# Current benign train accuracy: 0.4609375
# Current benign train loss: 1.4952619075775146
#
# Current batch: 300
# Current benign train accuracy: 0.421875
# Current benign train loss: 1.425891399383545
#
# Current batch: 400
# Current benign train accuracy: 0.453125
# Current benign train loss: 1.5099575519561768
#
# Current batch: 500
# Current benign train accuracy: 0.4609375
# Current benign train loss: 1.4219050407409668
#
# Current batch: 600
# Current benign train accuracy: 0.53125
# Current benign train loss: 1.5199733972549438
#
# Current batch: 700
# Current benign train accuracy: 0.5078125
# Current benign train loss: 1.3201484680175781
#
# Total benign train accuarcy: 45.967
# Total benign train loss: 1185.3109422326088
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 28.74
# Test average loss: 0.02706992859840393
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.1895122528076172
#
# Current batch: 100
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.3237419128417969
#
# Current batch: 200
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.0802719593048096
#
# Current batch: 300
# Current benign train accuracy: 0.5
# Current benign train loss: 1.4282829761505127
#
# Current batch: 400
# Current benign train accuracy: 0.5234375
# Current benign train loss: 1.3603373765945435
#
# Current batch: 500
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.2376476526260376
#
# Current batch: 600
# Current benign train accuracy: 0.609375
# Current benign train loss: 0.9384040832519531
#
# Current batch: 700
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.9853006601333618
#
# Total benign train accuarcy: 55.687
# Total benign train loss: 978.3872112631798
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 34.97
# Test average loss: 0.026554065847396852
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.65625
# Current benign train loss: 1.0196177959442139
#
# Current batch: 100
# Current benign train accuracy: 0.515625
# Current benign train loss: 1.2064208984375
#
# Current batch: 200
# Current benign train accuracy: 0.6328125
# Current benign train loss: 1.0930397510528564
#
# Current batch: 300
# Current benign train accuracy: 0.5390625
# Current benign train loss: 1.319251298904419
#
# Current batch: 400
# Current benign train accuracy: 0.6171875
# Current benign train loss: 0.9979410171508789
#
# Current batch: 500
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.2246527671813965
#
# Current batch: 600
# Current benign train accuracy: 0.6484375
# Current benign train loss: 0.9710890650749207
#
# Current batch: 700
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.109312891960144
#
# Total benign train accuarcy: 59.863
# Total benign train loss: 886.5715394616127
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 23.46
# Test average loss: 0.05293900136947632
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5
# Current benign train loss: 1.241832971572876
#
# Current batch: 100
# Current benign train accuracy: 0.625
# Current benign train loss: 0.9968014359474182
#
# Current batch: 200
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.0180120468139648
#
# Current batch: 300
# Current benign train accuracy: 0.65625
# Current benign train loss: 1.0364934206008911
#
# Current batch: 400
# Current benign train accuracy: 0.640625
# Current benign train loss: 0.9915882349014282
#
# Current batch: 500
# Current benign train accuracy: 0.6328125
# Current benign train loss: 0.9989166259765625
#
# Current batch: 600
# Current benign train accuracy: 0.6640625
# Current benign train loss: 0.9544193148612976
#
# Current batch: 700
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.2361162900924683
#
# Total benign train accuarcy: 64.194
# Total benign train loss: 788.0128127336502
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 17.81
# Test average loss: 0.04352700905799866
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6484375
# Current benign train loss: 0.8598395586013794
#
# Current batch: 100
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.8082431554794312
#
# Current batch: 200
# Current benign train accuracy: 0.6171875
# Current benign train loss: 0.9723575115203857
#
# Current batch: 300
# Current benign train accuracy: 0.65625
# Current benign train loss: 1.0089764595031738
#
# Current batch: 400
# Current benign train accuracy: 0.65625
# Current benign train loss: 1.0789930820465088
#
# Current batch: 500
# Current benign train accuracy: 0.6640625
# Current benign train loss: 0.9585065841674805
#
# Current batch: 600
# Current benign train accuracy: 0.65625
# Current benign train loss: 0.9515609741210938
#
# Current batch: 700
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.8118230700492859
#
# Total benign train accuarcy: 66.551
# Total benign train loss: 741.6390916705132
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 43.49
# Test average loss: 0.019083796799182894
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6640625
# Current benign train loss: 1.068535327911377
#
# Current batch: 100
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.7952573299407959
#
# Current batch: 200
# Current benign train accuracy: 0.6640625
# Current benign train loss: 0.8904571533203125
#
# Current batch: 300
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.9512330293655396
#
# Current batch: 400
# Current benign train accuracy: 0.625
# Current benign train loss: 0.963327944278717
#
# Current batch: 500
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7851396799087524
#
# Current batch: 600
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.8364490270614624
#
# Current batch: 700
# Current benign train accuracy: 0.6796875
# Current benign train loss: 0.8236190676689148
#
# Total benign train accuarcy: 68.963
# Total benign train loss: 690.9413493275642
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 42.06
# Test average loss: 0.021969191431999206
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.640625
# Current benign train loss: 1.0832796096801758
#
# Current batch: 100
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6831121444702148
#
# Current batch: 200
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.158203363418579
#
# Current batch: 300
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6770147681236267
#
# Current batch: 400
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.8136851787567139
#
# Current batch: 500
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.1107097864151
#
# Current batch: 600
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.583263099193573
#
# Current batch: 700
# Current benign train accuracy: 0.6796875
# Current benign train loss: 0.8457801938056946
#
# Total benign train accuarcy: 70.262
# Total benign train loss: 664.1756990551949
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 39.53
# Test average loss: 0.028024624991416933
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.709100067615509
#
# Current batch: 100
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.8182644844055176
#
# Current batch: 200
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.8013662099838257
#
# Current batch: 300
# Current benign train accuracy: 0.640625
# Current benign train loss: 1.017480731010437
#
# Current batch: 400
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.7647669315338135
#
# Current batch: 500
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.8634716272354126
#
# Current batch: 600
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.8557213544845581
#
# Current batch: 700
# Current benign train accuracy: 0.640625
# Current benign train loss: 0.9195876121520996
#
# Total benign train accuarcy: 72.158
# Total benign train loss: 628.9439116120338
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 27.43
# Test average loss: 0.04733910889625549
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6269774436950684
#
# Current batch: 100
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6633885502815247
#
# Current batch: 200
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.714358925819397
#
# Current batch: 300
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7993069887161255
#
# Current batch: 400
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7100732922554016
#
# Current batch: 500
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.7991424798965454
#
# Current batch: 600
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.907623827457428
#
# Current batch: 700
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7368602752685547
#
# Total benign train accuarcy: 72.831
# Total benign train loss: 608.9653232097626
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 39.53
# Test average loss: 0.03464839520454407
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.7521985769271851
#
# Current batch: 100
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7126096487045288
#
# Current batch: 200
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.6907336711883545
#
# Current batch: 300
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7191511392593384
#
# Current batch: 400
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6637853384017944
#
# Current batch: 500
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6274982690811157
#
# Current batch: 600
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6546851396560669
#
# Current batch: 700
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7333190441131592
#
# Total benign train accuarcy: 74.181
# Total benign train loss: 582.754267513752
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 11.99
# Test average loss: 0.08820040435791016
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6272771954536438
#
# Current batch: 100
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6936324834823608
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6886152029037476
#
# Current batch: 300
# Current benign train accuracy: 0.65625
# Current benign train loss: 0.9664256572723389
#
# Current batch: 400
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.5697174668312073
#
# Current batch: 500
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7286109328269958
#
# Current batch: 600
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5532054901123047
#
# Current batch: 700
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5317240953445435
#
# Total benign train accuarcy: 74.98
# Total benign train loss: 565.2192007899284
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 34.31
# Test average loss: 0.03528533465862274
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7546418309211731
#
# Current batch: 100
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6988810896873474
#
# Current batch: 200
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.8797922134399414
#
# Current batch: 300
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6395968198776245
#
# Current batch: 400
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.558532178401947
#
# Current batch: 500
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.661340594291687
#
# Current batch: 600
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.8661315441131592
#
# Current batch: 700
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.7495969533920288
#
# Total benign train accuarcy: 75.702
# Total benign train loss: 547.4772060513496
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 19.44
# Test average loss: 0.055006891775131225
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.789710283279419
#
# Current batch: 100
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7594271898269653
#
# Current batch: 200
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.9894434809684753
#
# Current batch: 300
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.691809356212616
#
# Current batch: 400
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6884484887123108
#
# Current batch: 500
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6476408243179321
#
# Current batch: 600
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.938014566898346
#
# Current batch: 700
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5700066089630127
#
# Total benign train accuarcy: 75.793
# Total benign train loss: 547.716657012701
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 42.61
# Test average loss: 0.029771081376075745
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6952071189880371
#
# Current batch: 100
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6447440981864929
#
# Current batch: 200
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6285725235939026
#
# Current batch: 300
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.8365602493286133
#
# Current batch: 400
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.6857665777206421
#
# Current batch: 500
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6830399036407471
#
# Current batch: 600
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.5375310182571411
#
# Current batch: 700
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5717036724090576
#
# Total benign train accuarcy: 76.637
# Total benign train loss: 532.4653840959072
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 23.12
# Test average loss: 0.044479377627372745
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.7130959033966064
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5336089134216309
#
# Current batch: 200
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.7336490750312805
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5147976279258728
#
# Current batch: 400
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5580509305000305
#
# Current batch: 500
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6271851658821106
#
# Current batch: 600
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.7211120128631592
#
# Current batch: 700
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5724120736122131
#
# Total benign train accuarcy: 77.343
# Total benign train loss: 516.2418080866337
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 17.09
# Test average loss: 0.05268401870727539
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.75
# Current benign train loss: 0.663262665271759
#
# Current batch: 100
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.703545331954956
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5228964686393738
#
# Current batch: 300
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7373948097229004
#
# Current batch: 400
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6172326803207397
#
# Current batch: 500
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.8679934144020081
#
# Current batch: 600
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6012917757034302
#
# Current batch: 700
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.9135187864303589
#
# Total benign train accuarcy: 77.557
# Total benign train loss: 509.8309039771557
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 32.77
# Test average loss: 0.0509013498544693
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6245693564414978
#
# Current batch: 100
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.572127103805542
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.49622607231140137
#
# Current batch: 300
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6936978697776794
#
# Current batch: 400
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.663408100605011
#
# Current batch: 500
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6534990072250366
#
# Current batch: 600
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5270218849182129
#
# Current batch: 700
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5308070182800293
#
# Total benign train accuarcy: 77.964
# Total benign train loss: 500.95115584135056
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 35.51
# Test average loss: 0.027998170137405395
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.6755359768867493
#
# Current batch: 100
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.8075434565544128
#
# Current batch: 200
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5425743460655212
#
# Current batch: 300
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6758425831794739
#
# Current batch: 400
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5475757718086243
#
# Current batch: 500
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7615870237350464
#
# Current batch: 600
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6983226537704468
#
# Current batch: 700
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6639333367347717
#
# Total benign train accuarcy: 78.459
# Total benign train loss: 488.0661663413048
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 12.38
# Test average loss: 0.08072666120529175
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.595405638217926
#
# Current batch: 100
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.8483821153640747
#
# Current batch: 200
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5452439785003662
#
# Current batch: 300
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.8411118984222412
#
# Current batch: 400
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6329182982444763
#
# Current batch: 500
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4540848731994629
#
# Current batch: 600
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.701849639415741
#
# Current batch: 700
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.8068990111351013
#
# Total benign train accuarcy: 78.581
# Total benign train loss: 488.8685943186283
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 30.08
# Test average loss: 0.04244516024589538
# Model Saved!
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7575495839118958
#
# Current batch: 100
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6758482456207275
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5156866908073425
#
# Current batch: 300
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.39650216698646545
#
# Current batch: 400
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6853443384170532
#
# Current batch: 500
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4919862747192383
#
# Current batch: 600
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.46193546056747437
#
# Current batch: 700
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.7950112223625183
#
# Total benign train accuarcy: 78.952
# Total benign train loss: 479.73360404372215
#
# [ Test epoch: 20 ]
#
# Test accuarcy: 35.89
# Test average loss: 0.048977089381217954
# Model Saved!
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5263128876686096
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5628445148468018
#
# Current batch: 200
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.658631443977356
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.48473238945007324
#
# Current batch: 400
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4376610815525055
#
# Current batch: 500
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5442030429840088
#
# Current batch: 600
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5851070284843445
#
# Current batch: 700
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6733034253120422
#
# Total benign train accuarcy: 79.413
# Total benign train loss: 470.85897520184517
#
# [ Test epoch: 21 ]
#
# Test accuarcy: 37.55
# Test average loss: 0.03472283325195313
# Model Saved!
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6512308120727539
#
# Current batch: 100
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5101781487464905
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.4456920623779297
#
# Current batch: 300
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6678736805915833
#
# Current batch: 400
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6695639491081238
#
# Current batch: 500
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7229350805282593
#
# Current batch: 600
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.9147667288780212
#
# Current batch: 700
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5452224612236023
#
# Total benign train accuarcy: 79.434
# Total benign train loss: 465.67498138546944
#
# [ Test epoch: 22 ]
#
# Test accuarcy: 26.87
# Test average loss: 0.04387637190818787
# Model Saved!
#
# [ Train epoch: 23 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.664825975894928
#
# Current batch: 100
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.652454137802124
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.45463526248931885
#
# Current batch: 300
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5940501689910889
#
# Current batch: 400
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5893735885620117
#
# Current batch: 500
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.570151686668396
#
# Current batch: 600
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5409802794456482
#
# Current batch: 700
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5331342816352844
#
# Total benign train accuarcy: 79.963
# Total benign train loss: 460.21217799186707
#
# [ Test epoch: 23 ]
#
# Test accuarcy: 37.6
# Test average loss: 0.04648330566883087
# Model Saved!
#
# [ Train epoch: 24 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.45408445596694946
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5383386611938477
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.57875657081604
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5480772852897644
#
# Current batch: 400
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7519261240959167
#
# Current batch: 500
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6172427535057068
#
# Current batch: 600
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3507286310195923
#
# Current batch: 700
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4514841139316559
#
# Total benign train accuarcy: 79.977
# Total benign train loss: 459.03399896621704
#
# [ Test epoch: 24 ]
#
# Test accuarcy: 11.31
# Test average loss: 0.07512748603820801
# Model Saved!
#
# [ Train epoch: 25 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6033969521522522
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.41495025157928467
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.5140382051467896
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6048663258552551
#
# Current batch: 400
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4715825915336609
#
# Current batch: 500
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6483224630355835
#
# Current batch: 600
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5525243878364563
#
# Current batch: 700
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6347313523292542
#
# Total benign train accuarcy: 80.125
# Total benign train loss: 456.3400027155876
#
# [ Test epoch: 25 ]
#
# Test accuarcy: 25.9
# Test average loss: 0.049484178233146665
# Model Saved!
#
# [ Train epoch: 26 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5404193997383118
#
# Current batch: 100
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6881445646286011
#
# Current batch: 200
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.509728729724884
#
# Current batch: 300
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6143697500228882
#
# Current batch: 400
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5281840562820435
#
# Current batch: 500
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.569116473197937
#
# Current batch: 600
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3928469717502594
#
# Current batch: 700
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6746147871017456
#
# Total benign train accuarcy: 80.732
# Total benign train loss: 437.0790226459503
#
# [ Test epoch: 26 ]
#
# Test accuarcy: 17.87
# Test average loss: 0.06547933049201965
# Model Saved!
#
# [ Train epoch: 27 ]
#
# Current batch: 0
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.49332737922668457
#
# Current batch: 100
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.7036259770393372
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.45487266778945923
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5681989789009094
#
# Current batch: 400
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5275880694389343
#
# Current batch: 500
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5528629422187805
#
# Current batch: 600
# Current benign train accuracy: 0.875
# Current benign train loss: 0.39028966426849365
#
# Current batch: 700
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.43904706835746765
#
# Total benign train accuarcy: 80.848
# Total benign train loss: 436.5471237003803
#
# [ Test epoch: 27 ]
#
# Test accuarcy: 22.87
# Test average loss: 0.051187951517105104
# Model Saved!
#
# [ Train epoch: 28 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4871286153793335
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.48466792702674866
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.7251437902450562
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.6207407712936401
#
# Current batch: 400
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7074559926986694
#
# Current batch: 500
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6582874059677124
#
# Current batch: 600
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6687377095222473
#
# Current batch: 700
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.6050539016723633
#
# Total benign train accuarcy: 80.846
# Total benign train loss: 440.15455225110054
#
# [ Test epoch: 28 ]
#
# Test accuarcy: 14.0
# Test average loss: 0.1016330909729004
# Model Saved!
#
# [ Train epoch: 29 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6490190029144287
#
# Current batch: 100
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.5638958215713501
#
# Current batch: 200
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3716060221195221
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.592969536781311
#
# Current batch: 400
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6587464809417725
#
# Current batch: 500
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6828476190567017
#
# Current batch: 600
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6038380265235901
#
# Current batch: 700
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.5748791098594666
#
# Total benign train accuarcy: 80.884
# Total benign train loss: 438.5623186826706
#
# [ Test epoch: 29 ]
#
# Test accuarcy: 11.75
# Test average loss: 0.06823046517372132
# Model Saved!
#
# [ Train epoch: 30 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6582306623458862
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5866013765335083
#
# Current batch: 200
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.46855053305625916
#
# Current batch: 300
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4336242079734802
#
# Current batch: 400
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.472072571516037
#
# Current batch: 500
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.41433945298194885
#
# Current batch: 600
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.44394752383232117
#
# Current batch: 700
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5164268612861633
#
# Total benign train accuarcy: 81.295
# Total benign train loss: 430.8564719557762
#
# [ Test epoch: 30 ]
#
# Test accuarcy: 20.63
# Test average loss: 0.07084954466819764
# Model Saved!
#
# [ Train epoch: 31 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7190213203430176
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5553697943687439
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5951945185661316
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5699528455734253
#
# Current batch: 400
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6884945631027222
#
# Current batch: 500
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.5097164511680603
#
# Current batch: 600
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5330930948257446
#
# Current batch: 700
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5212568640708923
#
# Total benign train accuarcy: 81.128
# Total benign train loss: 429.13739743828773
#
# [ Test epoch: 31 ]
#
# Test accuarcy: 26.35
# Test average loss: 0.059398276615142825
# Model Saved!
#
# [ Train epoch: 32 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5688855648040771
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.521332323551178
#
# Current batch: 200
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.40809449553489685
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.6111456155776978
#
# Current batch: 400
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6751104593276978
#
# Current batch: 500
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4723878800868988
#
# Current batch: 600
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5046170949935913
#
# Current batch: 700
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.537936270236969
#
# Total benign train accuarcy: 81.411
# Total benign train loss: 428.9229202270508
#
# [ Test epoch: 32 ]
#
# Test accuarcy: 13.53
# Test average loss: 0.057191177415847776
# Model Saved!
#
# [ Train epoch: 33 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.485725462436676
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4398631751537323
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4679044187068939
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5267200469970703
#
# Current batch: 400
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.47115686535835266
#
# Current batch: 500
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6560940742492676
#
# Current batch: 600
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5466034412384033
#
# Current batch: 700
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.40904736518859863
#
# Total benign train accuarcy: 81.527
# Total benign train loss: 423.873194783926
#
# [ Test epoch: 33 ]
#
# Test accuarcy: 39.98
# Test average loss: 0.03479427411556244
# Model Saved!
#
# [ Train epoch: 34 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.44294077157974243
#
# Current batch: 100
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6141923666000366
#
# Current batch: 200
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.5716137886047363
#
# Current batch: 300
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5707508325576782
#
# Current batch: 400
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.3535628616809845
#
# Current batch: 500
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5379006862640381
#
# Current batch: 600
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6643460988998413
#
# Current batch: 700
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5058949589729309
#
# Total benign train accuarcy: 81.632
# Total benign train loss: 422.10896268486977
#
# [ Test epoch: 34 ]
#
# Test accuarcy: 39.61
# Test average loss: 0.03147330162525177
# Model Saved!
#
# [ Train epoch: 35 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5770583748817444
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.48352259397506714
#
# Current batch: 200
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.38605695962905884
#
# Current batch: 300
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7370781898498535
#
# Current batch: 400
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.479634165763855
#
# Current batch: 500
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.7387580871582031
#
# Current batch: 600
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.611420750617981
#
# Current batch: 700
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5266520977020264
#
# Total benign train accuarcy: 81.481
# Total benign train loss: 423.2483747303486
#
# [ Test epoch: 35 ]
#
# Test accuarcy: 22.23
# Test average loss: 0.07140318913459778
# Model Saved!
#
# [ Train epoch: 36 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6821289658546448
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.45730745792388916
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4632836580276489
#
# Current batch: 300
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6162298917770386
#
# Current batch: 400
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4458453357219696
#
# Current batch: 500
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5536153316497803
#
# Current batch: 600
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4500528872013092
#
# Current batch: 700
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.49830907583236694
#
# Total benign train accuarcy: 81.651
# Total benign train loss: 420.9615808725357
#
# [ Test epoch: 36 ]
#
# Test accuarcy: 33.54
# Test average loss: 0.029794899201393128
# Model Saved!
#
# [ Train epoch: 37 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5648480653762817
#
# Current batch: 100
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.5936832427978516
#
# Current batch: 200
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.31487447023391724
#
# Current batch: 300
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4866929054260254
#
# Current batch: 400
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.3062250018119812
#
# Current batch: 500
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.36575186252593994
#
# Current batch: 600
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5692206025123596
#
# Current batch: 700
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5660447478294373
#
# Total benign train accuarcy: 82.267
# Total benign train loss: 409.69995334744453
#
# [ Test epoch: 37 ]
#
# Test accuarcy: 27.96
# Test average loss: 0.04012035548686981
# Model Saved!
#
# [ Train epoch: 38 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.32251977920532227
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4267822504043579
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.634951651096344
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5040499567985535
#
# Current batch: 400
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3224502503871918
#
# Current batch: 500
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4591290056705475
#
# Current batch: 600
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5523728728294373
#
# Current batch: 700
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6139269471168518
#
# Total benign train accuarcy: 81.853
# Total benign train loss: 416.23677265644073
#
# [ Test epoch: 38 ]
#
# Test accuarcy: 32.88
# Test average loss: 0.04374055721759796
# Model Saved!
#
# [ Train epoch: 39 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5951137542724609
#
# Current batch: 100
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5815752744674683
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.40923038125038147
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.46226245164871216
#
# Current batch: 400
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.4908549189567566
#
# Current batch: 500
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.45292893052101135
#
# Current batch: 600
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6303345561027527
#
# Current batch: 700
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6425586342811584
#
# Total benign train accuarcy: 82.175
# Total benign train loss: 408.31967225670815
#
# [ Test epoch: 39 ]
#
# Test accuarcy: 11.46
# Test average loss: 0.07792367100715637
# Model Saved!
#
# [ Train epoch: 40 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5100196599960327
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5180115103721619
#
# Current batch: 200
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6520670652389526
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5804324746131897
#
# Current batch: 400
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5367268919944763
#
# Current batch: 500
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5322992205619812
#
# Current batch: 600
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4180147349834442
#
# Current batch: 700
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.510278046131134
#
# Total benign train accuarcy: 82.33
# Total benign train loss: 404.84904143214226
#
# [ Test epoch: 40 ]
#
# Test accuarcy: 11.18
# Test average loss: 0.08488422145843506
# Model Saved!
#
# [ Train epoch: 41 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4559152126312256
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4673460125923157
#
# Current batch: 200
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.4114803671836853
#
# Current batch: 300
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.577241063117981
#
# Current batch: 400
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.44348740577697754
#
# Current batch: 500
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.32365283370018005
#
# Current batch: 600
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5483651757240295
#
# Current batch: 700
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5536285638809204
#
# Total benign train accuarcy: 82.072
# Total benign train loss: 412.0332728177309
#
# [ Test epoch: 41 ]
#
# Test accuarcy: 35.12
# Test average loss: 0.03961142964363098
# Model Saved!
#
# [ Train epoch: 42 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.4955194890499115
#
# Current batch: 100
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.703384518623352
#
# Current batch: 200
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3719937205314636
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.45369991660118103
#
# Current batch: 400
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.671557605266571
#
# Current batch: 500
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6991552710533142
#
# Current batch: 600
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4762117862701416
#
# Current batch: 700
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.8453553318977356
#
# Total benign train accuarcy: 82.369
# Total benign train loss: 406.77632604539394
#
# [ Test epoch: 42 ]
#
# Test accuarcy: 33.28
# Test average loss: 0.033996436405181886
# Model Saved!
#
# [ Train epoch: 43 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6109486818313599
#
# Current batch: 100
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6216210126876831
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5825570821762085
#
# Current batch: 300
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3609186112880707
#
# Current batch: 400
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5973167419433594
#
# Current batch: 500
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5853652358055115
#
# Current batch: 600
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5545113682746887
#
# Current batch: 700
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.42254334688186646
#
# Total benign train accuarcy: 82.638
# Total benign train loss: 400.5879609286785
#
# [ Test epoch: 43 ]
#
# Test accuarcy: 22.72
# Test average loss: 0.06242924485206604
# Model Saved!
#
# [ Train epoch: 44 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.31104299426078796
#
# Current batch: 100
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5305647253990173
#
# Current batch: 200
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5685362219810486
#
# Current batch: 300
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.7376382946968079
#
# Current batch: 400
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.3805694878101349
#
# Current batch: 500
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5567140579223633
#
# Current batch: 600
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.455306738615036
#
# Current batch: 700
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6110985279083252
#
# Total benign train accuarcy: 82.526
# Total benign train loss: 402.69476640224457
#
# [ Test epoch: 44 ]
#
# Test accuarcy: 20.86
# Test average loss: 0.06429515008926391
# Model Saved!
#
# [ Train epoch: 45 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3511084318161011
#
# Current batch: 100
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5016016364097595
#
# Current batch: 200
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5274709463119507
#
# Current batch: 300
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7439706325531006
#
# Current batch: 400
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5504792332649231
#
# Current batch: 500
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5636383891105652
#
# Current batch: 600
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3476770520210266
#
# Current batch: 700
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6398330330848694
#
# Total benign train accuarcy: 82.849
# Total benign train loss: 392.70052525401115
#
# [ Test epoch: 45 ]
#
# Test accuarcy: 26.66
# Test average loss: 0.046228506088256835
# Model Saved!
#
# [ Train epoch: 46 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7734375
# ...
# Current benign train loss: 0.1310960352420807
#
# Total benign train accuarcy: 96.237
# Total benign train loss: 95.17650055512786
#
# [ Test epoch: 84 ]
#
# Test accuarcy: 87.39
# Test average loss: 0.0040590113773942
# Model Saved!
#
# [ Train epoch: 85 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.18107326328754425
#
# Current batch: 100
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.15420375764369965
#
# Current batch: 200
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.14640909433364868
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11860638856887817
#
# Current batch: 400
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08802920579910278
#
# Current batch: 500
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.1492544710636139
#
# Current batch: 600
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.1611776500940323
#
# Current batch: 700
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08176886290311813
#
# Total benign train accuarcy: 96.387
# Total benign train loss: 93.33836762607098
#
# [ Test epoch: 85 ]
#
# Test accuarcy: 88.8
# Test average loss: 0.0036033203780651093
# Model Saved!
#
# [ Train epoch: 86 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.06258890777826309
#
# Current batch: 100
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.11933805048465729
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.1014280915260315
#
# Current batch: 300
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.0986115112900734
#
# Current batch: 400
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.17751231789588928
#
# Current batch: 500
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.1462724208831787
#
# Current batch: 600
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07673666626214981
#
# Current batch: 700
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08371397852897644
#
# Total benign train accuarcy: 96.365
# Total benign train loss: 92.26207876950502
#
# [ Test epoch: 86 ]
#
# Test accuarcy: 88.59
# Test average loss: 0.003536139151453972
# Model Saved!
#
# [ Train epoch: 87 ]
#
# Current batch: 0
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.157601997256279
#
# Current batch: 100
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.1946629136800766
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09700770676136017
#
# Current batch: 300
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08325790613889694
#
# Current batch: 400
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.15960773825645447
#
# Current batch: 500
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.10924679040908813
#
# Current batch: 600
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10474887490272522
#
# Current batch: 700
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.15190699696540833
#
# Total benign train accuarcy: 96.41
# Total benign train loss: 92.03029209002852
#
# [ Test epoch: 87 ]
#
# Test accuarcy: 89.16
# Test average loss: 0.003499139228463173
# Model Saved!
#
# [ Train epoch: 88 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10671669989824295
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.16904160380363464
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11332570016384125
#
# Current batch: 300
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.14196538925170898
#
# Current batch: 400
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11771799623966217
#
# Current batch: 500
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09878765046596527
#
# Current batch: 600
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.05681096389889717
#
# Current batch: 700
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09928344935178757
#
# Total benign train accuarcy: 96.42
# Total benign train loss: 91.47361816838384
#
# [ Test epoch: 88 ]
#
# Test accuarcy: 89.08
# Test average loss: 0.0034428053855895995
# Model Saved!
#
# [ Train epoch: 89 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09713781625032425
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.11220891028642654
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.07171983271837234
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08310196548700333
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.09290565550327301
#
# Current batch: 500
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.07806111872196198
#
# Current batch: 600
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1159297451376915
#
# Current batch: 700
# Current benign train accuracy: 1.0
# Current benign train loss: 0.067131906747818
#
# Total benign train accuarcy: 96.467
# Total benign train loss: 91.53970648348331
#
# [ Test epoch: 89 ]
#
# Test accuarcy: 89.15
# Test average loss: 0.0034404436483979227
# Model Saved!
#
# [ Train epoch: 90 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.10445196181535721
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09446454793214798
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.12785710394382477
#
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.1009937971830368
#
# Current batch: 400
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.13767752051353455
#
# Current batch: 500
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08214208483695984
#
# Current batch: 600
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.07650694996118546
#
# Current batch: 700
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11334140598773956
#
# Total benign train accuarcy: 96.364
# Total benign train loss: 92.29713965579867
#
# [ Test epoch: 90 ]
#
# Test accuarcy: 88.77
# Test average loss: 0.0035739965125918386
# Model Saved!
#
# [ Train epoch: 91 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.08991462737321854
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09196747094392776
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09645482152700424
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1419261246919632
#
# Current batch: 400
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.17697325348854065
#
# Current batch: 500
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.16769744455814362
#
# Current batch: 600
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.10761323571205139
#
# Current batch: 700
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.14396221935749054
#
# Total benign train accuarcy: 96.475
# Total benign train loss: 89.82427284121513
#
# [ Test epoch: 91 ]
#
# Test accuarcy: 87.78
# Test average loss: 0.0038905735924839972
# Model Saved!
#
# [ Train epoch: 92 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.17830416560173035
#
# Current batch: 100
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.21491645276546478
#
# Current batch: 200
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.12892267107963562
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.1101052463054657
#
# Current batch: 400
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.11390013247728348
#
# Current batch: 500
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.07981310039758682
#
# Current batch: 600
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.1446654051542282
#
# Current batch: 700
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.10606702417135239
#
# Total benign train accuarcy: 96.475
# Total benign train loss: 90.02435535937548
#
# [ Test epoch: 92 ]
#
# Test accuarcy: 87.59
# Test average loss: 0.003974304419755935
# Model Saved!
#
# [ Train epoch: 93 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10530256479978561
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11537785083055496
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.12430611252784729
#
# Current batch: 300
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.1937136948108673
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.063944011926651
#
# Current batch: 500
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.15870912373065948
#
# Current batch: 600
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1021028682589531
#
# Current batch: 700
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.11129841953516006
#
# Total benign train accuarcy: 96.435
# Total benign train loss: 90.32179781422019
#
# [ Test epoch: 93 ]
#
# Test accuarcy: 87.93
# Test average loss: 0.003783432164788246
# Model Saved!
#
# [ Train epoch: 94 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.10231392830610275
#
# Current batch: 100
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.0746515765786171
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09806055575609207
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.13196603953838348
#
# Current batch: 400
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.05695035681128502
#
# Current batch: 500
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.12808093428611755
#
# Current batch: 600
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09690596163272858
#
# Current batch: 700
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.08386767655611038
#
# Total benign train accuarcy: 96.571
# Total benign train loss: 88.99390611797571
#
# [ Test epoch: 94 ]
#
# Test accuarcy: 89.11
# Test average loss: 0.0035694925755262374
# Model Saved!
#
# [ Train epoch: 95 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.08676980435848236
#
# Current batch: 100
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.14891211688518524
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08999618887901306
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.08024553954601288
#
# Current batch: 400
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2268061637878418
#
# Current batch: 500
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10455329716205597
#
# Current batch: 600
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.12490033358335495
#
# Current batch: 700
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09627356380224228
#
# Total benign train accuarcy: 96.551
# Total benign train loss: 87.77367321401834
#
# [ Test epoch: 95 ]
#
# Test accuarcy: 89.21
# Test average loss: 0.003442425686120987
# Model Saved!
#
# [ Train epoch: 96 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08061017841100693
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.13494102656841278
#
# Current batch: 200
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.12527260184288025
#
# Current batch: 300
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09604544192552567
#
# Current batch: 400
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.13162103295326233
#
# Current batch: 500
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1533246636390686
#
# Current batch: 600
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.18890152871608734
#
# Current batch: 700
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.12558814883232117
#
# Total benign train accuarcy: 96.6
# Total benign train loss: 88.03808174282312
#
# [ Test epoch: 96 ]
#
# Test accuarcy: 89.06
# Test average loss: 0.003552202698588371
# Model Saved!
#
# [ Train epoch: 97 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.06938312947750092
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.15339383482933044
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.097423255443573
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.12270934879779816
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.06916851550340652
#
# Current batch: 500
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2669278383255005
#
# Current batch: 600
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.11520558595657349
#
# Current batch: 700
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.11353054642677307
#
# Total benign train accuarcy: 96.609
# Total benign train loss: 86.608314614743
#
# [ Test epoch: 97 ]
#
# Test accuarcy: 88.41
# Test average loss: 0.003734339675307274
# Model Saved!
#
# [ Train epoch: 98 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09295619279146194
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.12320221960544586
#
# Current batch: 200
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.237127423286438
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.0868593379855156
#
# Current batch: 400
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.12181934714317322
#
# Current batch: 500
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.14605076611042023
#
# Current batch: 600
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.09394394606351852
#
# Current batch: 700
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1485379934310913
#
# Total benign train accuarcy: 96.563
# Total benign train loss: 87.91898989677429
#
# [ Test epoch: 98 ]
#
# Test accuarcy: 87.54
# Test average loss: 0.004277883364260196
# Model Saved!
#
# [ Train epoch: 99 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.0986790880560875
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07284577935934067
#
# Current batch: 200
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.16261054575443268
#
# Current batch: 300
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09059923142194748
#
# Current batch: 400
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.12498660385608673
#
# Current batch: 500
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1417565792798996
#
# Current batch: 600
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1273137927055359
#
# Current batch: 700
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09935587644577026
#
# Total benign train accuarcy: 96.528
# Total benign train loss: 87.09073002636433
#
# [ Test epoch: 99 ]
#
# Test accuarcy: 88.92
# Test average loss: 0.003484465280175209
# Model Saved!
