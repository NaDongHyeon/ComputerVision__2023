# %% [markdown]
# <a href="https://colab.research.google.com/github/ndb796/Deep-Learning-Paper-Review-and-Practice/blob/master/code_practices/ResNet18_CIFAR10_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
import torch
import random
import torch.backends.cudnn as cudnn

torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)
cudnn.benchmark = False
cudnn.deterministic = True
random.seed(0)

# %% [markdown]
# #### ResNet18 모델 정의 및 인스턴스 초기화

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os


# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)  # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)  # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential()  # identity인 경우
        if stride != 1:  # stride가 1이 아니라면, Identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.sigmoid(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)  # (핵심) skip connection
        out = F.sigmoid(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes  # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.sigmoid(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# #### 데이터셋(Dataset) 다운로드 및 불러오기

# %%
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import ConcatDataset

data_transformations = {
    "basic": transforms.Compose([
        transforms.ToTensor()
    ]),
    "crop_flip": transforms.Compose([  # 크롭 + 뒤집기
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor()
    ])
}

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=data_transformations["basic"])
train_aug_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=data_transformations["crop_flip"])
augmented_train_data = ConcatDataset((train_dataset, train_aug_dataset))

test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=data_transformations["basic"])

train_loader = torch.utils.data.DataLoader(augmented_train_data, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# #### 환경 설정 및 학습(Training) 함수 정의

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.1
file_name = 'resnet18_cifar10.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 50:
        lr = 0.01
    if epoch >= 80:
        lr = 0.001
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# #### 학습(Training) 진행

# %% [markdown]
# * 대략 20번의 epoch 이후에도 85%가량의 test accuracy를 얻을 수 있습니다.

# %%
# for epoch in range(0, 200):
for epoch in range(0, 100):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current benign train accuracy: 0.109375
# Current benign train loss: 2.307521104812622
#
# Current batch: 100
# Current benign train accuracy: 0.1640625
# Current benign train loss: 2.539579391479492
#
# Current batch: 200
# Current benign train accuracy: 0.2578125
# Current benign train loss: 2.114412307739258
#
# Current batch: 300
# Current benign train accuracy: 0.2734375
# Current benign train loss: 2.1262428760528564
#
# Current batch: 400
# Current benign train accuracy: 0.2734375
# Current benign train loss: 2.177952766418457
#
# Current batch: 500
# Current benign train accuracy: 0.21875
# Current benign train loss: 2.0478103160858154
#
# Current batch: 600
# Current benign train accuracy: 0.3046875
# Current benign train loss: 1.8728878498077393
#
# Current batch: 700
# Current benign train accuracy: 0.3046875
# Current benign train loss: 2.02083683013916
#
# Total benign train accuarcy: 25.668
# Total benign train loss: 2075.289119243622
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 25.53
# Test average loss: 0.024289859795570374
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.296875
# Current benign train loss: 1.845551609992981
#
# Current batch: 100
# Current benign train accuracy: 0.359375
# Current benign train loss: 1.8947502374649048
#
# Current batch: 200
# Current benign train accuracy: 0.3828125
# Current benign train loss: 1.6223621368408203
#
# Current batch: 300
# Current benign train accuracy: 0.421875
# Current benign train loss: 1.5495065450668335
#
# Current batch: 400
# Current benign train accuracy: 0.4375
# Current benign train loss: 1.6040942668914795
#
# Current batch: 500
# Current benign train accuracy: 0.484375
# Current benign train loss: 1.5239157676696777
#
# Current batch: 600
# Current benign train accuracy: 0.453125
# Current benign train loss: 1.4958128929138184
#
# Current batch: 700
# Current benign train accuracy: 0.4453125
# Current benign train loss: 1.4108812808990479
#
# Total benign train accuarcy: 42.369
# Total benign train loss: 1247.1497633457184
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 22.35
# Test average loss: 0.02805789041519165
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5234375
# Current benign train loss: 1.3412435054779053
#
# Current batch: 100
# Current benign train accuracy: 0.5078125
# Current benign train loss: 1.382565975189209
#
# Current batch: 200
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.216554045677185
#
# Current batch: 300
# Current benign train accuracy: 0.4921875
# Current benign train loss: 1.3945870399475098
#
# Current batch: 400
# Current benign train accuracy: 0.5078125
# Current benign train loss: 1.3526794910430908
#
# Current batch: 500
# Current benign train accuracy: 0.5546875
# Current benign train loss: 1.2653541564941406
#
# Current batch: 600
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.0350315570831299
#
# Current batch: 700
# Current benign train accuracy: 0.6640625
# Current benign train loss: 0.987615168094635
#
# Total benign train accuarcy: 54.722
# Total benign train loss: 994.6562544107437
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 38.47
# Test average loss: 0.025544984662532806
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.9658622145652771
#
# Current batch: 100
# Current benign train accuracy: 0.5078125
# Current benign train loss: 1.1915274858474731
#
# Current batch: 200
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.1848403215408325
#
# Current batch: 300
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.2907437086105347
#
# Current batch: 400
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.0698691606521606
#
# Current batch: 500
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.1264677047729492
#
# Current batch: 600
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.0404289960861206
#
# Current batch: 700
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.0487675666809082
#
# Total benign train accuarcy: 59.323
# Total benign train loss: 899.25871270895
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 23.95
# Test average loss: 0.03533195269107819
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.515625
# Current benign train loss: 1.2869353294372559
#
# Current batch: 100
# Current benign train accuracy: 0.5390625
# Current benign train loss: 1.0872043371200562
#
# Current batch: 200
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.0042306184768677
#
# Current batch: 300
# Current benign train accuracy: 0.6328125
# Current benign train loss: 1.0266627073287964
#
# Current batch: 400
# Current benign train accuracy: 0.6640625
# Current benign train loss: 0.9965146780014038
#
# Current batch: 500
# Current benign train accuracy: 0.625
# Current benign train loss: 1.0112582445144653
#
# Current batch: 600
# Current benign train accuracy: 0.65625
# Current benign train loss: 1.0345854759216309
#
# Current batch: 700
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.1902594566345215
#
# Total benign train accuarcy: 63.502
# Total benign train loss: 805.4556547999382
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 23.7
# Test average loss: 0.04706611795425415
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.8748092651367188
#
# Current batch: 100
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.8092717528343201
#
# Current batch: 200
# Current benign train accuracy: 0.65625
# Current benign train loss: 1.0424755811691284
#
# Current batch: 300
# Current benign train accuracy: 0.65625
# Current benign train loss: 1.0521243810653687
#
# Current batch: 400
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.0649983882904053
#
# Current batch: 500
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.0257028341293335
#
# Current batch: 600
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.8905208110809326
#
# Current batch: 700
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.8732554316520691
#
# Total benign train accuarcy: 66.1
# Total benign train loss: 750.5493757724762
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 38.52
# Test average loss: 0.03529233348369598
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.625
# Current benign train loss: 1.0460624694824219
#
# Current batch: 100
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7577421069145203
#
# Current batch: 200
# Current benign train accuracy: 0.640625
# Current benign train loss: 0.8886829018592834
#
# Current batch: 300
# Current benign train accuracy: 0.65625
# Current benign train loss: 0.8913896083831787
#
# Current batch: 400
# Current benign train accuracy: 0.625
# Current benign train loss: 1.037089467048645
#
# Current batch: 500
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.8134130239486694
#
# Current batch: 600
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.8425523042678833
#
# Current batch: 700
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.753883957862854
#
# Total benign train accuarcy: 68.322
# Total benign train loss: 701.5380121469498
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 29.36
# Test average loss: 0.03489652979373932
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6328125
# Current benign train loss: 1.0936654806137085
#
# Current batch: 100
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6504621505737305
#
# Current batch: 200
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.1198370456695557
#
# Current batch: 300
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7878487706184387
#
# Current batch: 400
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.9614549875259399
#
# Current batch: 500
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.1371842622756958
#
# Current batch: 600
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6202374696731567
#
# Current batch: 700
# Current benign train accuracy: 0.6640625
# Current benign train loss: 0.8652185797691345
#
# Total benign train accuarcy: 69.987
# Total benign train loss: 669.5775601267815
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 21.56
# Test average loss: 0.047410511803627015
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7257240414619446
#
# Current batch: 100
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.8072293996810913
#
# Current batch: 200
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.8203608393669128
#
# Current batch: 300
# Current benign train accuracy: 0.671875
# Current benign train loss: 1.0028486251831055
#
# Current batch: 400
# Current benign train accuracy: 0.65625
# Current benign train loss: 0.8880292773246765
#
# Current batch: 500
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.8620502352714539
#
# Current batch: 600
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.8254691362380981
#
# Current batch: 700
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.9039877653121948
#
# Total benign train accuarcy: 71.608
# Total benign train loss: 634.8887826800346
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 30.8
# Test average loss: 0.0332707533121109
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6694298982620239
#
# Current batch: 100
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.6954097747802734
#
# Current batch: 200
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.8289950489997864
#
# Current batch: 300
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.7798240184783936
#
# Current batch: 400
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.6076633334159851
#
# Current batch: 500
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7587475180625916
#
# Current batch: 600
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.9699313640594482
#
# Current batch: 700
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.7793639898300171
#
# Total benign train accuarcy: 72.86
# Total benign train loss: 612.1348344385624
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 11.28
# Test average loss: 0.07668027033805846
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.8383417725563049
#
# Current batch: 100
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.75679612159729
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.7494148015975952
#
# Current batch: 300
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7572952508926392
#
# Current batch: 400
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4964595139026642
#
# Current batch: 500
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6431058049201965
#
# Current batch: 600
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5840767621994019
#
# Current batch: 700
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7466893196105957
#
# Total benign train accuarcy: 73.879
# Total benign train loss: 588.1893810033798
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 21.89
# Test average loss: 0.045982375049591066
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6888516545295715
#
# Current batch: 100
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7580147981643677
#
# Current batch: 200
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7308734655380249
#
# Current batch: 300
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.9689362645149231
#
# Current batch: 400
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5910231471061707
#
# Current batch: 500
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7413116693496704
#
# Current batch: 600
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5297877788543701
#
# Current batch: 700
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.610191285610199
#
# Total benign train accuarcy: 74.693
# Total benign train loss: 572.0693388581276
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 23.79
# Test average loss: 0.056096017408370974
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.7087735533714294
#
# Current batch: 100
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7926973700523376
#
# Current batch: 200
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.9475486874580383
#
# Current batch: 300
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6969712376594543
#
# Current batch: 400
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5414130687713623
#
# Current batch: 500
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6528500914573669
#
# Current batch: 600
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.9236676096916199
#
# Current batch: 700
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7435805797576904
#
# Total benign train accuarcy: 75.472
# Total benign train loss: 553.5031161606312
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 25.79
# Test average loss: 0.04118203389644623
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7060648798942566
#
# Current batch: 100
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7350541949272156
#
# Current batch: 200
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.8868460655212402
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.669421374797821
#
# Current batch: 400
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7068834900856018
#
# Current batch: 500
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6809829473495483
#
# Current batch: 600
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.9566631317138672
#
# Current batch: 700
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.5986440777778625
#
# Total benign train accuarcy: 75.834
# Total benign train loss: 549.1960023641586
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 36.25
# Test average loss: 0.029566121864318846
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7357885837554932
#
# Current batch: 100
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.624921977519989
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5429364442825317
#
# Current batch: 300
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6964311003684998
#
# Current batch: 400
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5575948357582092
#
# Current batch: 500
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7294281721115112
#
# Current batch: 600
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5444645285606384
#
# Current batch: 700
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.605731725692749
#
# Total benign train accuarcy: 76.437
# Total benign train loss: 534.4101877510548
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 33.75
# Test average loss: 0.039278092265129086
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.6984007954597473
#
# Current batch: 100
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5032318830490112
#
# Current batch: 200
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7377529740333557
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5403804779052734
#
# Current batch: 400
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6028009653091431
#
# Current batch: 500
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.601931631565094
#
# Current batch: 600
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.6843281984329224
#
# Current batch: 700
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5984209179878235
#
# Total benign train accuarcy: 77.27
# Total benign train loss: 517.7358998656273
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 19.59
# Test average loss: 0.04756404099464417
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7188701629638672
#
# Current batch: 100
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7838038206100464
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6125439405441284
#
# Current batch: 300
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.7150423526763916
#
# Current batch: 400
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6313290596008301
#
# Current batch: 500
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.8830412030220032
#
# Current batch: 600
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6551456451416016
#
# Current batch: 700
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.8731265664100647
#
# Total benign train accuarcy: 77.394
# Total benign train loss: 512.0825250446796
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 26.22
# Test average loss: 0.05059915895462036
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6253442764282227
#
# Current batch: 100
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.6588420271873474
#
# Current batch: 200
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5812826156616211
#
# Current batch: 300
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.803934633731842
#
# Current batch: 400
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.591875433921814
#
# Current batch: 500
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7961463332176208
#
# Current batch: 600
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5986995697021484
#
# Current batch: 700
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6069917678833008
#
# Total benign train accuarcy: 77.752
# Total benign train loss: 504.7274151146412
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 29.03
# Test average loss: 0.04248711621761322
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.729870617389679
#
# Current batch: 100
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.7348877191543579
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5562525391578674
#
# Current batch: 300
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7019027471542358
#
# Current batch: 400
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.6024104952812195
#
# Current batch: 500
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7284017205238342
#
# Current batch: 600
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7991275191307068
#
# Current batch: 700
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6460874676704407
#
# Total benign train accuarcy: 78.259
# Total benign train loss: 494.35393980145454
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 29.06
# Test average loss: 0.03783905065059662
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6162044405937195
#
# Current batch: 100
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.836211621761322
#
# Current batch: 200
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6180806159973145
#
# Current batch: 300
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7413841485977173
#
# Current batch: 400
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7131005525588989
#
# Current batch: 500
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5618749856948853
#
# Current batch: 600
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6151108741760254
#
# Current batch: 700
# Current benign train accuracy: 0.75
# Current benign train loss: 0.791318416595459
#
# Total benign train accuarcy: 78.287
# Total benign train loss: 492.37335124611855
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 18.36
# Test average loss: 0.05163025455474853
# Model Saved!
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.6715896129608154
#
# Current batch: 100
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6726719737052917
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4964205324649811
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.4807671010494232
#
# Current batch: 400
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5217946767807007
#
# Current batch: 500
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5128190517425537
#
# Current batch: 600
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5400996208190918
#
# Current batch: 700
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.7719215154647827
#
# Total benign train accuarcy: 78.638
# Total benign train loss: 485.3124993443489
#
# [ Test epoch: 20 ]
#
# Test accuarcy: 19.6
# Test average loss: 0.05973334460258484
# Model Saved!
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6412891149520874
#
# Current batch: 100
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5065420269966125
#
# Current batch: 200
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6981918215751648
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.485078364610672
#
# Current batch: 400
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3582489490509033
#
# Current batch: 500
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4410029351711273
#
# Current batch: 600
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.587701678276062
#
# Current batch: 700
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.716917097568512
#
# Total benign train accuarcy: 79.222
# Total benign train loss: 470.6126765012741
#
# [ Test epoch: 21 ]
#
# Test accuarcy: 14.0
# Test average loss: 0.05984180870056152
# Model Saved!
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6248716115951538
#
# Current batch: 100
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.47494399547576904
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5222921371459961
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6523721218109131
#
# Current batch: 400
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5996559858322144
#
# Current batch: 500
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.7331368923187256
#
# Current batch: 600
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.9358471035957336
#
# Current batch: 700
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.624945342540741
#
# Total benign train accuarcy: 79.407
# Total benign train loss: 471.51778492331505
#
# [ Test epoch: 22 ]
#
# Test accuarcy: 29.09
# Test average loss: 0.04011178183555603
# Model Saved!
#
# [ Train epoch: 23 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6698125004768372
#
# Current batch: 100
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6469109058380127
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4957084357738495
#
# Current batch: 300
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.48603153228759766
#
# Current batch: 400
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6235823035240173
#
# Current batch: 500
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5608286261558533
#
# Current batch: 600
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5451869368553162
#
# Current batch: 700
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5341793298721313
#
# Total benign train accuarcy: 79.676
# Total benign train loss: 463.5508652329445
#
# [ Test epoch: 23 ]
#
# Test accuarcy: 36.08
# Test average loss: 0.02974861681461334
# Model Saved!
#
# [ Train epoch: 24 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.44623708724975586
#
# Current batch: 100
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.486179381608963
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5465344786643982
#
# Current batch: 300
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6272799372673035
#
# Current batch: 400
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.7282078862190247
#
# Current batch: 500
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5583065748214722
#
# Current batch: 600
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4787173569202423
#
# Current batch: 700
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.5094399452209473
#
# Total benign train accuarcy: 79.902
# Total benign train loss: 461.3037914633751
#
# [ Test epoch: 24 ]
#
# Test accuarcy: 35.58
# Test average loss: 0.041366988730430605
# Model Saved!
#
# [ Train epoch: 25 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6982959508895874
#
# Current batch: 100
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.385960191488266
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.5847885608673096
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6357801556587219
#
# Current batch: 400
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.41511762142181396
#
# Current batch: 500
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6030937433242798
#
# Current batch: 600
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5511038303375244
#
# Current batch: 700
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5539971590042114
#
# Total benign train accuarcy: 79.976
# Total benign train loss: 458.8159163594246
#
# [ Test epoch: 25 ]
#
# Test accuarcy: 29.64
# Test average loss: 0.029609590482711792
# Model Saved!
#
# [ Train epoch: 26 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4672486186027527
#
# Current batch: 100
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5479406714439392
#
# Current batch: 200
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.49680808186531067
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5798904299736023
#
# Current batch: 400
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.547899067401886
#
# Current batch: 500
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5092579126358032
#
# Current batch: 600
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.49898049235343933
#
# Current batch: 700
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.6481585502624512
#
# Total benign train accuarcy: 80.391
# Total benign train loss: 443.29433223605156
#
# [ Test epoch: 26 ]
#
# Test accuarcy: 13.13
# Test average loss: 0.06351326169967651
# Model Saved!
#
# [ Train epoch: 27 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.47325849533081055
#
# Current batch: 100
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5303739309310913
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4674542546272278
#
# Current batch: 300
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6185367107391357
#
# Current batch: 400
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4997302293777466
#
# Current batch: 500
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6720770001411438
#
# Current batch: 600
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.48847776651382446
#
# Current batch: 700
# Current benign train accuracy: 0.875
# Current benign train loss: 0.42890167236328125
#
# Total benign train accuarcy: 80.49
# Total benign train loss: 444.3888172507286
#
# [ Test epoch: 27 ]
#
# Test accuarcy: 31.48
# Test average loss: 0.05149904518127441
# Model Saved!
#
# [ Train epoch: 28 ]
#
# Current batch: 0
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6137539148330688
#
# Current batch: 100
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4950678050518036
#
# Current batch: 200
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6101798415184021
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5840269327163696
#
# Current batch: 400
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.7137632369995117
#
# Current batch: 500
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6960129737854004
#
# Current batch: 600
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7568747997283936
#
# Current batch: 700
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.588245689868927
#
# Total benign train accuarcy: 80.32
# Total benign train loss: 448.62919667363167
#
# [ Test epoch: 28 ]
#
# Test accuarcy: 27.42
# Test average loss: 0.06414796605110168
# Model Saved!
#
# [ Train epoch: 29 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6491573452949524
#
# Current batch: 100
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5881015658378601
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.37699300050735474
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6581180095672607
#
# Current batch: 400
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6130923628807068
#
# Current batch: 500
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.6846634149551392
#
# Current batch: 600
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6251440048217773
#
# Current batch: 700
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.5649288892745972
#
# Total benign train accuarcy: 80.74
# Total benign train loss: 440.87815022468567
#
# [ Test epoch: 29 ]
#
# Test accuarcy: 36.33
# Test average loss: 0.029619951391220093
# Model Saved!
#
# [ Train epoch: 30 ]
#
# Current batch: 0
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6728481650352478
#
# Current batch: 100
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.5609966516494751
#
# Current batch: 200
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5041099786758423
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.375295490026474
#
# Current batch: 400
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4806458353996277
#
# Current batch: 500
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.48060351610183716
#
# Current batch: 600
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.475690096616745
#
# Current batch: 700
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.445182740688324
#
# Total benign train accuarcy: 80.974
# Total benign train loss: 435.01434421539307
#
# [ Test epoch: 30 ]
#
# Test accuarcy: 39.56
# Test average loss: 0.03077623600959778
# Model Saved!
#
# [ Train epoch: 31 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.667105495929718
#
# Current batch: 100
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.3952326774597168
#
# Current batch: 200
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.643983006477356
#
# Current batch: 300
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5710217356681824
#
# Current batch: 400
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6095477938652039
#
# Current batch: 500
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5387716293334961
#
# Current batch: 600
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5019705891609192
#
# Current batch: 700
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.49412834644317627
#
# Total benign train accuarcy: 81.138
# Total benign train loss: 431.40233087539673
#
# [ Test epoch: 31 ]
#
# Test accuarcy: 28.2
# Test average loss: 0.035606733465194704
# Model Saved!
#
# [ Train epoch: 32 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6400370597839355
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5044735670089722
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4491294026374817
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5100736021995544
#
# Current batch: 400
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6233468055725098
#
# Current batch: 500
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4851321578025818
#
# Current batch: 600
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5410578846931458
#
# Current batch: 700
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6603677272796631
#
# Total benign train accuarcy: 81.282
# Total benign train loss: 432.5643338561058
#
# [ Test epoch: 32 ]
#
# Test accuarcy: 30.03
# Test average loss: 0.04654509422779083
# Model Saved!
#
# [ Train epoch: 33 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5925531983375549
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4394068121910095
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5540709495544434
#
# Current batch: 300
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6281031966209412
#
# Current batch: 400
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5309434533119202
#
# Current batch: 500
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6650833487510681
#
# Current batch: 600
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.48011547327041626
#
# Current batch: 700
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4915398955345154
#
# Total benign train accuarcy: 81.5
# Total benign train loss: 424.9155945330858
#
# [ Test epoch: 33 ]
#
# Test accuarcy: 29.99
# Test average loss: 0.03944457986354828
# Model Saved!
#
# [ Train epoch: 34 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5157644748687744
#
# Current batch: 100
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6479738354682922
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.6063960194587708
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.48268359899520874
#
# Current batch: 400
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3437795341014862
#
# Current batch: 500
# Current benign train accuracy: 0.75
# Current benign train loss: 0.5835160613059998
#
# Current batch: 600
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6461495161056519
#
# Current batch: 700
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6381001472473145
#
# Total benign train accuarcy: 81.634
# Total benign train loss: 424.15904083848
#
# [ Test epoch: 34 ]
#
# Test accuarcy: 31.1
# Test average loss: 0.0360402916431427
# Model Saved!
#
# [ Train epoch: 35 ]
#
# Current batch: 0
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5504908561706543
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4792913794517517
#
# Current batch: 200
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3751159608364105
#
# Current batch: 300
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.7028288245201111
#
# Current batch: 400
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.37175750732421875
#
# Current batch: 500
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5825363397598267
#
# Current batch: 600
# Current benign train accuracy: 0.75
# Current benign train loss: 0.656919002532959
#
# Current batch: 700
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.46705836057662964
#
# Total benign train accuarcy: 81.395
# Total benign train loss: 421.8160126209259
#
# [ Test epoch: 35 ]
#
# Test accuarcy: 20.46
# Test average loss: 0.06342635135650634
# Model Saved!
#
# [ Train epoch: 36 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.6001824736595154
#
# Current batch: 100
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.617411196231842
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5464350581169128
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5570980906486511
#
# Current batch: 400
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5016279220581055
#
# Current batch: 500
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.49308261275291443
#
# Current batch: 600
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6361845135688782
#
# Current batch: 700
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5597829222679138
#
# Total benign train accuarcy: 81.635
# Total benign train loss: 422.0611367225647
#
# [ Test epoch: 36 ]
#
# Test accuarcy: 23.45
# Test average loss: 0.04711034018993378
# Model Saved!
#
# [ Train epoch: 37 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5117566585540771
#
# Current batch: 100
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.607420802116394
#
# Current batch: 200
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.43008750677108765
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.42596665024757385
#
# Current batch: 400
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.33440133929252625
#
# Current batch: 500
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.3703456521034241
#
# Current batch: 600
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7154257297515869
#
# Current batch: 700
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5209894776344299
#
# Total benign train accuarcy: 81.685
# Total benign train loss: 418.78136390447617
#
# [ Test epoch: 37 ]
#
# Test accuarcy: 21.54
# Test average loss: 0.06505422019958496
# Model Saved!
#
# [ Train epoch: 38 ]
#
# Current batch: 0
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3910280168056488
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5219116806983948
#
# Current batch: 200
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6550858616828918
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5353224873542786
#
# Current batch: 400
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.408408522605896
#
# Current batch: 500
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6199739575386047
#
# Current batch: 600
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5258498191833496
#
# Current batch: 700
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.5494722127914429
#
# Total benign train accuarcy: 81.798
# Total benign train loss: 417.049973487854
#
# [ Test epoch: 38 ]
#
# Test accuarcy: 44.3
# Test average loss: 0.036845205974578854
# Model Saved!
#
# [ Train epoch: 39 ]
#
# Current batch: 0
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6647767424583435
#
# Current batch: 100
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5956565737724304
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4444645643234253
#
# Current batch: 300
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4370666444301605
#
# Current batch: 400
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6101112961769104
#
# Current batch: 500
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5710132718086243
#
# Current batch: 600
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5680958032608032
#
# Current batch: 700
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5532848238945007
#
# Total benign train accuarcy: 82.079
# Total benign train loss: 412.2166899740696
#
# [ Test epoch: 39 ]
#
# Test accuarcy: 20.69
# Test average loss: 0.08299232459068298
# Model Saved!
#
# [ Train epoch: 40 ]
#
# Current batch: 0
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6415933966636658
#
# Current batch: 100
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.5795295238494873
#
# Current batch: 200
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5790938138961792
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.609417736530304
#
# Current batch: 400
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.460225373506546
#
# Current batch: 500
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.49387508630752563
#
# Current batch: 600
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.42637747526168823
#
# Current batch: 700
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5564590096473694
#
# Total benign train accuarcy: 82.41
# Total benign train loss: 404.620079010725
#
# [ Test epoch: 40 ]
#
# Test accuarcy: 10.0
# Test average loss: 0.11701934366226197
# Model Saved!
#
# [ Train epoch: 41 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4575086236000061
#
# Current batch: 100
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.4834061861038208
#
# Current batch: 200
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3895508348941803
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5166548490524292
#
# Current batch: 400
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5391367673873901
#
# Current batch: 500
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3427696228027344
#
# Current batch: 600
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6046717762947083
#
# Current batch: 700
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5073952674865723
#
# Total benign train accuarcy: 82.063
# Total benign train loss: 412.4983588606119
#
# [ Test epoch: 41 ]
#
# Test accuarcy: 26.5
# Test average loss: 0.04241107566356659
# Model Saved!
#
# [ Train epoch: 42 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5430135726928711
#
# Current batch: 100
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6927419304847717
#
# Current batch: 200
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.39219406247138977
#
# Current batch: 300
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.4017583727836609
#
# Current batch: 400
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6668264865875244
#
# Current batch: 500
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.5664499402046204
#
# Current batch: 600
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.47203218936920166
#
# Current batch: 700
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6534909009933472
#
# Total benign train accuarcy: 82.206
# Total benign train loss: 409.13666903972626
#
# [ Test epoch: 42 ]
#
# Test accuarcy: 21.67
# Test average loss: 0.051743311071395875
# Model Saved!
#
# [ Train epoch: 43 ]
#
# Current batch: 0
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.554671585559845
#
# Current batch: 100
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5201892852783203
#
# Current batch: 200
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6289419531822205
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4554576873779297
#
# Current batch: 400
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5965335965156555
#
# Current batch: 500
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5184789896011353
#
# Current batch: 600
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5533387660980225
#
# Current batch: 700
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.488618940114975
#
# Total benign train accuarcy: 82.449
# Total benign train loss: 402.3947503268719
#
# [ Test epoch: 43 ]
#
# Test accuarcy: 18.24
# Test average loss: 0.047441661524772645
# Model Saved!
#
# [ Train epoch: 44 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.32843685150146484
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5773418545722961
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5598877668380737
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.6653638482093811
#
# Current batch: 400
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5093405246734619
#
# Current batch: 500
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5569595694541931
#
# Current batch: 600
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5226781964302063
#
# Current batch: 700
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6503991484642029
#
# Total benign train accuarcy: 82.384
# Total benign train loss: 404.8105542808771
#
# [ Test epoch: 44 ]
#
# Test accuarcy: 19.97
# Test average loss: 0.07680134816169738
# Model Saved!
#
# [ Train epoch: 45 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3832932412624359
#
# Current batch: 100
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5647633075714111
#
# Current batch: 200
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.4196329712867737
#
# Current batch: 300
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6341181397438049
#
# Current batch: 400
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6401000618934631
#
# Current batch: 500
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.5985168814659119
#
# Current batch: 600
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3978818953037262
#
# Current batch: 700
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5639456510543823
#
# Total benign train accuarcy: 82.752
# Total benign train loss: 396.00143936276436
#
# [ Test epoch: 45 ]
#
# Test accuarcy: 11.05
# Test average loss: 0.10140531644821167
# Model Saved!
#
# [ Train epoch: 46 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5825638175010681
#
# ...
# Current benign train loss: 0.11687694489955902
#
# Total benign train accuarcy: 96.321
# Total benign train loss: 93.98019890487194
#
# [ Test epoch: 84 ]
#
# Test accuarcy: 89.72
# Test average loss: 0.0032665276117622853
# Model Saved!
#
# [ Train epoch: 85 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.16487671434879303
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.1827821135520935
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.11007453501224518
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1733817160129547
#
# Current batch: 400
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.1084059551358223
#
# Current batch: 500
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.15972702205181122
#
# Current batch: 600
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.10703299194574356
#
# Current batch: 700
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.0547480583190918
#
# Total benign train accuarcy: 96.348
# Total benign train loss: 93.90480886213481
#
# [ Test epoch: 85 ]
#
# Test accuarcy: 89.57
# Test average loss: 0.003265597829222679
# Model Saved!
#
# [ Train epoch: 86 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.14571534097194672
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.14241696894168854
#
# Current batch: 200
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.16877730190753937
#
# Current batch: 300
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09599926322698593
#
# Current batch: 400
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.17185208201408386
#
# Current batch: 500
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.12351588904857635
#
# Current batch: 600
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09261287748813629
#
# Current batch: 700
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11540692299604416
#
# Total benign train accuarcy: 96.393
# Total benign train loss: 92.01730454713106
#
# [ Test epoch: 86 ]
#
# Test accuarcy: 89.7
# Test average loss: 0.0033411308392882347
# Model Saved!
#
# [ Train epoch: 87 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.10513806343078613
#
# Current batch: 100
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.2155320644378662
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10879988968372345
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.07543294131755829
#
# Current batch: 400
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1580108255147934
#
# Current batch: 500
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.10156457871198654
#
# Current batch: 600
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11837177723646164
#
# Current batch: 700
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.1588011384010315
#
# Total benign train accuarcy: 96.514
# Total benign train loss: 90.78319504857063
#
# [ Test epoch: 87 ]
#
# Test accuarcy: 89.05
# Test average loss: 0.003424240516126156
# Model Saved!
#
# [ Train epoch: 88 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.07403295487165451
#
# Current batch: 100
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.12589485943317413
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11946357786655426
#
# Current batch: 300
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.19748298823833466
#
# Current batch: 400
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.13405625522136688
#
# Current batch: 500
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10448804497718811
#
# Current batch: 600
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10283030569553375
#
# Current batch: 700
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.14400646090507507
#
# Total benign train accuarcy: 96.46
# Total benign train loss: 90.58399438485503
#
# [ Test epoch: 88 ]
#
# Test accuarcy: 89.08
# Test average loss: 0.003456389072537422
# Model Saved!
#
# [ Train epoch: 89 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.07667281478643417
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.155634343624115
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.0595010444521904
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08978400379419327
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.09110799431800842
#
# Current batch: 500
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11092357337474823
#
# Current batch: 600
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10405558347702026
#
# Current batch: 700
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.06634729355573654
#
# Total benign train accuarcy: 96.488
# Total benign train loss: 89.18459614366293
#
# [ Test epoch: 89 ]
#
# Test accuarcy: 89.22
# Test average loss: 0.0034561763145029545
# Model Saved!
#
# [ Train epoch: 90 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.07896362245082855
#
# Current batch: 100
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.12704509496688843
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.09733109921216965
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.14029760658740997
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.07466516643762589
#
# Current batch: 500
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.0702267736196518
#
# Current batch: 600
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08807079493999481
#
# Current batch: 700
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1198882982134819
#
# Total benign train accuarcy: 96.536
# Total benign train loss: 89.032305624336
#
# [ Test epoch: 90 ]
#
# Test accuarcy: 89.62
# Test average loss: 0.003328996579349041
# Model Saved!
#
# [ Train epoch: 91 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10122060775756836
#
# Current batch: 100
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.11586523801088333
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.07215110212564468
#
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.17719635367393494
#
# Current batch: 400
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.16998228430747986
#
# Current batch: 500
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.14630310237407684
#
# Current batch: 600
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.15015161037445068
#
# Current batch: 700
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1612790822982788
#
# Total benign train accuarcy: 96.613
# Total benign train loss: 87.46773111447692
#
# [ Test epoch: 91 ]
#
# Test accuarcy: 89.15
# Test average loss: 0.003445275402069092
# Model Saved!
#
# [ Train epoch: 92 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.16251754760742188
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1498568207025528
#
# Current batch: 200
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1227295994758606
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.14065615832805634
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.07535145431756973
#
# Current batch: 500
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09877756983041763
#
# Current batch: 600
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10837496072053909
#
# Current batch: 700
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1337909996509552
#
# Total benign train accuarcy: 96.481
# Total benign train loss: 89.43413857370615
#
# [ Test epoch: 92 ]
#
# Test accuarcy: 88.33
# Test average loss: 0.0038795604735612868
# Model Saved!
#
# [ Train epoch: 93 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.12419674545526505
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11860588192939758
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.09603191912174225
#
# Current batch: 300
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.20818957686424255
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.06005474925041199
#
# Current batch: 500
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.09224344789981842
#
# Current batch: 600
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.0897919312119484
#
# Current batch: 700
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.12663085758686066
#
# Total benign train accuarcy: 96.623
# Total benign train loss: 87.90943624824286
#
# [ Test epoch: 93 ]
#
# Test accuarcy: 88.17
# Test average loss: 0.003719758594036102
# Model Saved!
#
# [ Train epoch: 94 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1231694146990776
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.12188877165317535
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.07897651940584183
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11859922111034393
#
# Current batch: 400
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.06871988624334335
#
# Current batch: 500
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11820545047521591
#
# Current batch: 600
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08384424448013306
#
# Current batch: 700
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.05917133390903473
#
# Total benign train accuarcy: 96.588
# Total benign train loss: 87.7873029075563
#
# [ Test epoch: 94 ]
#
# Test accuarcy: 89.22
# Test average loss: 0.0033821373224258424
# Model Saved!
#
# [ Train epoch: 95 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.10125034302473068
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.16400842368602753
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09191477298736572
#
# Current batch: 300
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09679877012968063
#
# Current batch: 400
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2141491174697876
#
# Current batch: 500
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.06789155304431915
#
# Current batch: 600
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.14430980384349823
#
# Current batch: 700
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.15286393463611603
#
# Total benign train accuarcy: 96.648
# Total benign train loss: 85.73166796937585
#
# [ Test epoch: 95 ]
#
# Test accuarcy: 89.25
# Test average loss: 0.003427656024694443
# Model Saved!
#
# [ Train epoch: 96 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.06312001496553421
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.14146290719509125
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11419440060853958
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.048238325864076614
#
# Current batch: 400
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10870485007762909
#
# Current batch: 500
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.1704975664615631
#
# Current batch: 600
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.16740480065345764
#
# Current batch: 700
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.155373215675354
#
# Total benign train accuarcy: 96.764
# Total benign train loss: 84.62141663953662
#
# [ Test epoch: 96 ]
#
# Test accuarcy: 89.11
# Test average loss: 0.003344682751595974
# Model Saved!
#
# [ Train epoch: 97 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08293046802282333
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.13396413624286652
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.12414711713790894
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1155686154961586
#
# Current batch: 400
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.07386597990989685
#
# Current batch: 500
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.24825352430343628
#
# Current batch: 600
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1271844506263733
#
# Current batch: 700
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1593516319990158
#
# Total benign train accuarcy: 96.721
# Total benign train loss: 84.7686070073396
#
# [ Test epoch: 97 ]
#
# Test accuarcy: 88.88
# Test average loss: 0.0035083266779780387
# Model Saved!
#
# [ Train epoch: 98 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08010244369506836
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08201347291469574
#
# Current batch: 200
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.20048004388809204
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.04789024218916893
#
# Current batch: 400
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.14596040546894073
#
# Current batch: 500
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11115679144859314
#
# Current batch: 600
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.06839554756879807
#
# Current batch: 700
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.15196090936660767
#
# Total benign train accuarcy: 96.81
# Total benign train loss: 84.28673116862774
#
# [ Test epoch: 98 ]
#
# Test accuarcy: 89.28
# Test average loss: 0.0035164484933018682
# Model Saved!
#
# [ Train epoch: 99 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09835295379161835
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08763623982667923
#
# Current batch: 200
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.15060661733150482
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11986658722162247
#
# Current batch: 400
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11556345969438553
#
# Current batch: 500
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.15818458795547485
#
# Current batch: 600
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.11959593743085861
#
# Current batch: 700
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.0944594144821167
#
# Total benign train accuarcy: 96.744
# Total benign train loss: 84.22246650233865
#
# [ Test epoch: 99 ]
#
# Test accuarcy: 89.0
# Test average loss: 0.003540084420144558
# Model Saved!
