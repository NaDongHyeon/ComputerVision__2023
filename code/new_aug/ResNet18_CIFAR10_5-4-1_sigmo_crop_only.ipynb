# %% [markdown]
# <a href="https://colab.research.google.com/github/ndb796/Deep-Learning-Paper-Review-and-Practice/blob/master/code_practices/ResNet18_CIFAR10_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
import torch
import random
import torch.backends.cudnn as cudnn

torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)
cudnn.benchmark = False
cudnn.deterministic = True
random.seed(0)

# %% [markdown]
# #### ResNet18 모델 정의 및 인스턴스 초기화

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os


# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)  # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)  # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential()  # identity인 경우
        if stride != 1:  # stride가 1이 아니라면, Identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.sigmoid(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)  # (핵심) skip connection
        out = F.sigmoid(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes  # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.sigmoid(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# #### 데이터셋(Dataset) 다운로드 및 불러오기

# %%
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import ConcatDataset

data_transformations = {
    "basic": transforms.Compose([
        transforms.ToTensor()
    ]),
    "crop_flip": transforms.Compose([  # 크롭 + 뒤집기
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor()
    ])
}

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=data_transformations["basic"])
train_aug_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=data_transformations["crop_flip"])
augmented_train_data = ConcatDataset((train_dataset, train_aug_dataset))

test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=data_transformations["basic"])

train_loader = torch.utils.data.DataLoader(augmented_train_data, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# #### 환경 설정 및 학습(Training) 함수 정의

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.1
file_name = 'resnet18_cifar10.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 50:
        lr = 0.01
    if epoch >= 90:
        lr = 0.001
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# #### 학습(Training) 진행

# %% [markdown]
# * 대략 20번의 epoch 이후에도 85%가량의 test accuracy를 얻을 수 있습니다.

# %%
# for epoch in range(0, 200):
for epoch in range(0, 100):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current benign train accuracy: 0.109375
# Current benign train loss: 2.3075203895568848
#
# Current batch: 100
# Current benign train accuracy: 0.140625
# Current benign train loss: 5.608727931976318
#
# Current batch: 200
# Current benign train accuracy: 0.1796875
# Current benign train loss: 1.9678326845169067
#
# Current batch: 300
# Current benign train accuracy: 0.265625
# Current benign train loss: 1.9886605739593506
#
# Current batch: 400
# Current benign train accuracy: 0.2734375
# Current benign train loss: 2.0432980060577393
#
# Current batch: 500
# Current benign train accuracy: 0.2265625
# Current benign train loss: 2.0586295127868652
#
# Current batch: 600
# Current benign train accuracy: 0.2890625
# Current benign train loss: 1.8180097341537476
#
# Current batch: 700
# Current benign train accuracy: 0.25
# Current benign train loss: 2.042320489883423
#
# Total benign train accuarcy: 24.567
# Total benign train loss: 2160.909787297249
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 25.29
# Test average loss: 0.02171189113855362
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.296875
# Current benign train loss: 1.8282666206359863
#
# Current batch: 100
# Current benign train accuracy: 0.3515625
# Current benign train loss: 1.939739465713501
#
# Current batch: 200
# Current benign train accuracy: 0.390625
# Current benign train loss: 1.5967833995819092
#
# Current batch: 300
# Current benign train accuracy: 0.4140625
# Current benign train loss: 1.6267516613006592
#
# Current batch: 400
# Current benign train accuracy: 0.421875
# Current benign train loss: 1.6820082664489746
#
# Current batch: 500
# Current benign train accuracy: 0.4296875
# Current benign train loss: 1.6151067018508911
#
# Current batch: 600
# Current benign train accuracy: 0.390625
# Current benign train loss: 1.6088237762451172
#
# Current batch: 700
# Current benign train accuracy: 0.5
# Current benign train loss: 1.3738932609558105
#
# Total benign train accuarcy: 42.124
# Total benign train loss: 1252.9543294906616
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 25.71
# Test average loss: 0.024065689027309416
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5
# Current benign train loss: 1.3308078050613403
#
# Current batch: 100
# Current benign train accuracy: 0.4921875
# Current benign train loss: 1.449029803276062
#
# Current batch: 200
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.2305045127868652
#
# Current batch: 300
# Current benign train accuracy: 0.484375
# Current benign train loss: 1.4401562213897705
#
# Current batch: 400
# Current benign train accuracy: 0.515625
# Current benign train loss: 1.3368784189224243
#
# Current batch: 500
# Current benign train accuracy: 0.5546875
# Current benign train loss: 1.2849743366241455
#
# Current batch: 600
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.1037769317626953
#
# Current batch: 700
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.069543480873108
#
# Total benign train accuarcy: 53.677
# Total benign train loss: 1011.528355717659
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 35.45
# Test average loss: 0.021037525272369385
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6796875
# Current benign train loss: 0.9882794618606567
#
# Current batch: 100
# Current benign train accuracy: 0.5234375
# Current benign train loss: 1.226911187171936
#
# Current batch: 200
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.2086139917373657
#
# Current batch: 300
# Current benign train accuracy: 0.546875
# Current benign train loss: 1.3318595886230469
#
# Current batch: 400
# Current benign train accuracy: 0.640625
# Current benign train loss: 1.08903968334198
#
# Current batch: 500
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.2173622846603394
#
# Current batch: 600
# Current benign train accuracy: 0.6484375
# Current benign train loss: 0.9288024306297302
#
# Current batch: 700
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.1459274291992188
#
# Total benign train accuarcy: 58.627
# Total benign train loss: 910.473894238472
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 17.65
# Test average loss: 0.04994750051498413
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4921875
# Current benign train loss: 1.4048857688903809
#
# Current batch: 100
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.0394428968429565
#
# Current batch: 200
# Current benign train accuracy: 0.625
# Current benign train loss: 1.0203132629394531
#
# Current batch: 300
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.0967028141021729
#
# Current batch: 400
# Current benign train accuracy: 0.625
# Current benign train loss: 1.0131220817565918
#
# Current batch: 500
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.0189789533615112
#
# Current batch: 600
# Current benign train accuracy: 0.640625
# Current benign train loss: 1.1050981283187866
#
# Current batch: 700
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.2377772331237793
#
# Total benign train accuarcy: 62.994
# Total benign train loss: 814.6433905959129
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 36.59
# Test average loss: 0.029512327313423157
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.8774598836898804
#
# Current batch: 100
# Current benign train accuracy: 0.6796875
# Current benign train loss: 0.8490242958068848
#
# Current batch: 200
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.0177961587905884
#
# Current batch: 300
# Current benign train accuracy: 0.6640625
# Current benign train loss: 0.96836918592453
#
# Current batch: 400
# Current benign train accuracy: 0.625
# Current benign train loss: 1.0832269191741943
#
# Current batch: 500
# Current benign train accuracy: 0.609375
# Current benign train loss: 0.9846450686454773
#
# Current batch: 600
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.0389723777770996
#
# Current batch: 700
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.839453399181366
#
# Total benign train accuarcy: 65.526
# Total benign train loss: 760.7665318250656
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 35.66
# Test average loss: 0.025237946891784668
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.0639076232910156
#
# Current batch: 100
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.8761942386627197
#
# Current batch: 200
# Current benign train accuracy: 0.609375
# Current benign train loss: 0.9193605184555054
#
# Current batch: 300
# Current benign train accuracy: 0.65625
# Current benign train loss: 0.9445253610610962
#
# Current batch: 400
# Current benign train accuracy: 0.625
# Current benign train loss: 1.0378657579421997
#
# Current batch: 500
# Current benign train accuracy: 0.6796875
# Current benign train loss: 0.8932433724403381
#
# Current batch: 600
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.8565465211868286
#
# Current batch: 700
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.8281828761100769
#
# Total benign train accuarcy: 67.813
# Total benign train loss: 714.3037158846855
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 31.94
# Test average loss: 0.02732104358673096
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.1586207151412964
#
# Current batch: 100
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.701702892780304
#
# Current batch: 200
# Current benign train accuracy: 0.625
# Current benign train loss: 1.1882656812667847
#
# Current batch: 300
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.7966268062591553
#
# Current batch: 400
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.8587237000465393
#
# Current batch: 500
# Current benign train accuracy: 0.625
# Current benign train loss: 1.0697660446166992
#
# Current batch: 600
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.6434337496757507
#
# Current batch: 700
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.8080155849456787
#
# Total benign train accuarcy: 69.357
# Total benign train loss: 680.1104673147202
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 27.31
# Test average loss: 0.03865781455039978
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.7241015434265137
#
# Current batch: 100
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.8307138681411743
#
# Current batch: 200
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.8566529750823975
#
# Current batch: 300
# Current benign train accuracy: 0.625
# Current benign train loss: 0.9912300705909729
#
# Current batch: 400
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.8470415472984314
#
# Current batch: 500
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.8931683897972107
#
# Current batch: 600
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.8740266561508179
#
# Current batch: 700
# Current benign train accuracy: 0.65625
# Current benign train loss: 0.9457411766052246
#
# Total benign train accuarcy: 71.188
# Total benign train loss: 644.2749248743057
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 15.34
# Test average loss: 0.08789879517555237
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6770947575569153
#
# Current batch: 100
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7212399840354919
#
# Current batch: 200
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7757437229156494
#
# Current batch: 300
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.8303284049034119
#
# Current batch: 400
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7009187936782837
#
# Current batch: 500
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7278873324394226
#
# Current batch: 600
# Current benign train accuracy: 0.6328125
# Current benign train loss: 0.9065943360328674
#
# Current batch: 700
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.7789458632469177
#
# Total benign train accuarcy: 72.211
# Total benign train loss: 622.1469504833221
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 30.62
# Test average loss: 0.04816911103725433
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7872090935707092
#
# Current batch: 100
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.697300136089325
#
# Current batch: 200
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.78360515832901
#
# Current batch: 300
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7122384309768677
#
# Current batch: 400
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5674753785133362
#
# Current batch: 500
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6059616804122925
#
# Current batch: 600
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6131839752197266
#
# Current batch: 700
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6911317110061646
#
# Total benign train accuarcy: 73.477
# Total benign train loss: 599.2995928227901
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 12.01
# Test average loss: 0.0807076247215271
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7454289793968201
#
# Current batch: 100
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6634093523025513
#
# Current batch: 200
# Current benign train accuracy: 0.75
# Current benign train loss: 0.745589017868042
#
# Current batch: 300
# Current benign train accuracy: 0.640625
# Current benign train loss: 0.9885960817337036
#
# Current batch: 400
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6058331727981567
#
# Current batch: 500
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7606903910636902
#
# Current batch: 600
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5312164425849915
#
# Current batch: 700
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5495940446853638
#
# Total benign train accuarcy: 74.573
# Total benign train loss: 574.2405748963356
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 41.04
# Test average loss: 0.029113917660713196
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7055363059043884
#
# Current batch: 100
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7318118214607239
#
# Current batch: 200
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.962451696395874
#
# Current batch: 300
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.7182709574699402
#
# Current batch: 400
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5466774106025696
#
# Current batch: 500
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.6154170036315918
#
# Current batch: 600
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.8773483037948608
#
# Current batch: 700
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.7610160708427429
#
# Total benign train accuarcy: 75.125
# Total benign train loss: 562.4756552278996
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 15.63
# Test average loss: 0.05251732754707336
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.8323013186454773
#
# Current batch: 100
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7625734210014343
#
# Current batch: 200
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.9080870151519775
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6065376400947571
#
# Current batch: 400
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6700628995895386
#
# Current batch: 500
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6933866739273071
#
# Current batch: 600
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.8766189813613892
#
# Current batch: 700
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.597579836845398
#
# Total benign train accuarcy: 75.755
# Total benign train loss: 548.5949549078941
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 25.34
# Test average loss: 0.032031201124191284
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6859159469604492
#
# Current batch: 100
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6832448244094849
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6320405602455139
#
# Current batch: 300
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.7734503746032715
#
# Current batch: 400
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.8064815998077393
#
# Current batch: 500
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6561189889907837
#
# Current batch: 600
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.654477596282959
#
# Current batch: 700
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6601461172103882
#
# Total benign train accuarcy: 76.335
# Total benign train loss: 538.9911613166332
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 14.76
# Test average loss: 0.05684223923683167
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7147380709648132
#
# Current batch: 100
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6182645559310913
#
# Current batch: 200
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7601763010025024
#
# Current batch: 300
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6202874779701233
#
# Current batch: 400
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.54031902551651
#
# Current batch: 500
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7037290334701538
#
# Current batch: 600
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7302472591400146
#
# Current batch: 700
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6374073028564453
#
# Total benign train accuarcy: 76.968
# Total benign train loss: 521.039706081152
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 34.3
# Test average loss: 0.02755545823574066
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6465945243835449
#
# Current batch: 100
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7635148167610168
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5894228219985962
#
# Current batch: 300
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7035470008850098
#
# Current batch: 400
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6506657004356384
#
# Current batch: 500
# Current benign train accuracy: 0.6796875
# Current benign train loss: 0.9731850028038025
#
# Current batch: 600
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6265304088592529
#
# Current batch: 700
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.9656780958175659
#
# Total benign train accuarcy: 77.437
# Total benign train loss: 513.0680146217346
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 37.41
# Test average loss: 0.031060539817810057
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.6025436520576477
#
# Current batch: 100
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6091566681861877
#
# Current batch: 200
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.5802047848701477
#
# Current batch: 300
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7737504839897156
#
# Current batch: 400
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6589874625205994
#
# Current batch: 500
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.7103681564331055
#
# Current batch: 600
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5519005656242371
#
# Current batch: 700
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.528486430644989
#
# Total benign train accuarcy: 77.806
# Total benign train loss: 504.7782777249813
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 29.88
# Test average loss: 0.0612188512802124
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6977940201759338
#
# Current batch: 100
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6893088221549988
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.49462074041366577
#
# Current batch: 300
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.7314927577972412
#
# Current batch: 400
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6122985482215881
#
# Current batch: 500
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.735838770866394
#
# Current batch: 600
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7355611324310303
#
# Current batch: 700
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5985107421875
#
# Total benign train accuarcy: 78.073
# Total benign train loss: 499.70014306902885
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 55.85
# Test average loss: 0.014855751192569733
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6314285397529602
#
# Current batch: 100
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.7994412183761597
#
# Current batch: 200
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5380181670188904
#
# Current batch: 300
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7590725421905518
#
# Current batch: 400
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6454124450683594
#
# Current batch: 500
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.4804845452308655
#
# Current batch: 600
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6907651424407959
#
# Current batch: 700
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.7745670080184937
#
# Total benign train accuarcy: 78.446
# Total benign train loss: 491.98559057712555
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 27.19
# Test average loss: 0.03385691990852356
# Model Saved!
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7585169076919556
#
# Current batch: 100
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6094623804092407
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.498917818069458
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.48221075534820557
#
# Current batch: 400
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6304750442504883
#
# Current batch: 500
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4779697358608246
#
# Current batch: 600
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5118188858032227
#
# Current batch: 700
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.8075007200241089
#
# Total benign train accuarcy: 78.588
# Total benign train loss: 485.20028188824654
#
# [ Test epoch: 20 ]
#
# Test accuarcy: 49.34
# Test average loss: 0.01797139391899109
# Model Saved!
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6968435645103455
#
# Current batch: 100
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6232050657272339
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6871239542961121
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.4793732464313507
#
# Current batch: 400
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4155806005001068
#
# Current batch: 500
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.46420061588287354
#
# Current batch: 600
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.5381473898887634
#
# Current batch: 700
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7375262379646301
#
# Total benign train accuarcy: 79.184
# Total benign train loss: 473.6853134036064
#
# [ Test epoch: 21 ]
#
# Test accuarcy: 32.77
# Test average loss: 0.03714849610328674
# Model Saved!
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6100280284881592
#
# Current batch: 100
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.523546576499939
#
# Current batch: 200
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5185441970825195
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6500232815742493
#
# Current batch: 400
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6377800107002258
#
# Current batch: 500
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7053435444831848
#
# Current batch: 600
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.986437201499939
#
# Current batch: 700
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.603174090385437
#
# Total benign train accuarcy: 79.268
# Total benign train loss: 471.028367459774
#
# [ Test epoch: 22 ]
#
# Test accuarcy: 25.18
# Test average loss: 0.03446090934276581
# Model Saved!
#
# [ Train epoch: 23 ]
#
# Current batch: 0
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6965160369873047
#
# Current batch: 100
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6496997475624084
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.48892325162887573
#
# Current batch: 300
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4787263572216034
#
# Current batch: 400
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6499143838882446
#
# Current batch: 500
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5576707124710083
#
# Current batch: 600
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.601284384727478
#
# Current batch: 700
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4348987340927124
#
# Total benign train accuarcy: 79.802
# Total benign train loss: 463.5265942811966
#
# [ Test epoch: 23 ]
#
# Test accuarcy: 42.39
# Test average loss: 0.029988055515289307
# Model Saved!
#
# [ Train epoch: 24 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.46119964122772217
#
# Current batch: 100
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5674795508384705
#
# Current batch: 200
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6116503477096558
#
# Current batch: 300
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7002815008163452
#
# Current batch: 400
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6465171575546265
#
# Current batch: 500
# Current benign train accuracy: 0.75
# Current benign train loss: 0.604522705078125
#
# Current batch: 600
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4556812644004822
#
# Current batch: 700
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5668861269950867
#
# Total benign train accuarcy: 79.913
# Total benign train loss: 459.9993668794632
#
# [ Test epoch: 24 ]
#
# Test accuarcy: 16.07
# Test average loss: 0.051178714561462404
# Model Saved!
#
# [ Train epoch: 25 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7184913754463196
#
# Current batch: 100
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4189949631690979
#
# Current batch: 200
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6369531154632568
#
# Current batch: 300
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6557027101516724
#
# Current batch: 400
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.45748093724250793
#
# Current batch: 500
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5469080209732056
#
# Current batch: 600
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.575262188911438
#
# Current batch: 700
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6105130910873413
#
# Total benign train accuarcy: 79.842
# Total benign train loss: 461.7247143089771
#
# [ Test epoch: 25 ]
#
# Test accuarcy: 17.98
# Test average loss: 0.058048967456817625
# Model Saved!
#
# [ Train epoch: 26 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4819222390651703
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5362273454666138
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5421651005744934
#
# Current batch: 300
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.5881032347679138
#
# Current batch: 400
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.553667426109314
#
# Current batch: 500
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.548331081867218
#
# Current batch: 600
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.483234703540802
#
# Current batch: 700
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.695565938949585
#
# Total benign train accuarcy: 80.415
# Total benign train loss: 445.73133808374405
#
# [ Test epoch: 26 ]
#
# Test accuarcy: 52.47
# Test average loss: 0.01916519945859909
# Model Saved!
#
# [ Train epoch: 27 ]
#
# Current batch: 0
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5600155591964722
#
# Current batch: 100
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.596352756023407
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.4944727420806885
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5161562561988831
#
# Current batch: 400
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5392473936080933
#
# Current batch: 500
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6567814350128174
#
# Current batch: 600
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5500900745391846
#
# Current batch: 700
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5029078125953674
#
# Total benign train accuarcy: 80.332
# Total benign train loss: 447.50584679841995
#
# [ Test epoch: 27 ]
#
# Test accuarcy: 10.04
# Test average loss: 0.09859650135040283
# Model Saved!
#
# [ Train epoch: 28 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.5433228015899658
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.46444442868232727
#
# Current batch: 200
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7255027890205383
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5593060851097107
#
# Current batch: 400
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7998072504997253
#
# Current batch: 500
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6518255472183228
#
# Current batch: 600
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6683139801025391
#
# Current batch: 700
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5497296452522278
#
# Total benign train accuarcy: 80.646
# Total benign train loss: 446.02970507740974
#
# [ Test epoch: 28 ]
#
# Test accuarcy: 22.49
# Test average loss: 0.08919529247283936
# Model Saved!
#
# [ Train epoch: 29 ]
#
# Current batch: 0
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6165139675140381
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4980214536190033
#
# Current batch: 200
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.31343331933021545
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.6257619857788086
#
# Current batch: 400
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6372458338737488
#
# Current batch: 500
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6610162854194641
#
# Current batch: 600
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6009947657585144
#
# Current batch: 700
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5539868474006653
#
# Total benign train accuarcy: 80.798
# Total benign train loss: 441.38161623477936
#
# [ Test epoch: 29 ]
#
# Test accuarcy: 22.2
# Test average loss: 0.042982668614387515
# Model Saved!
#
# [ Train epoch: 30 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6042446494102478
#
# Current batch: 100
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5286140441894531
#
# Current batch: 200
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5173877477645874
#
# Current batch: 300
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.41077980399131775
#
# Current batch: 400
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.49481889605522156
#
# Current batch: 500
# Current benign train accuracy: 0.875
# Current benign train loss: 0.4351885914802551
#
# Current batch: 600
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.43125784397125244
#
# Current batch: 700
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4389551281929016
#
# Total benign train accuarcy: 80.987
# Total benign train loss: 434.4095464348793
#
# [ Test epoch: 30 ]
#
# Test accuarcy: 15.76
# Test average loss: 0.06463892588615418
# Model Saved!
#
# [ Train epoch: 31 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.7395861744880676
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.48002180457115173
#
# Current batch: 200
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6137464642524719
#
# Current batch: 300
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.6696347594261169
#
# Current batch: 400
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6306933164596558
#
# Current batch: 500
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4891308546066284
#
# Current batch: 600
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.572525680065155
#
# Current batch: 700
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4580770432949066
#
# Total benign train accuarcy: 81.087
# Total benign train loss: 431.7380307018757
#
# [ Test epoch: 31 ]
#
# Test accuarcy: 37.53
# Test average loss: 0.03266026668548584
# Model Saved!
#
# [ Train epoch: 32 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5496748089790344
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.5022773146629333
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4555593430995941
#
# Current batch: 300
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5842191576957703
#
# Current batch: 400
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5708674192428589
#
# Current batch: 500
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4948158860206604
#
# Current batch: 600
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5012363791465759
#
# Current batch: 700
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4868524968624115
#
# Total benign train accuarcy: 81.156
# Total benign train loss: 431.6089795231819
#
# [ Test epoch: 32 ]
#
# Test accuarcy: 37.99
# Test average loss: 0.03292747027873993
# Model Saved!
#
# [ Train epoch: 33 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5323597192764282
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4039376378059387
#
# Current batch: 200
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6478574275970459
#
# Current batch: 300
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5090225338935852
#
# Current batch: 400
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5063302516937256
#
# Current batch: 500
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6244341731071472
#
# Current batch: 600
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4106590449810028
#
# Current batch: 700
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4114975035190582
#
# Total benign train accuarcy: 81.53
# Total benign train loss: 424.99201077222824
#
# [ Test epoch: 33 ]
#
# Test accuarcy: 44.71
# Test average loss: 0.026743881869316102
# Model Saved!
#
# [ Train epoch: 34 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4774484634399414
#
# Current batch: 100
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.70750492811203
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5653002262115479
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.47570061683654785
#
# Current batch: 400
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.37800127267837524
#
# Current batch: 500
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5210502743721008
#
# Current batch: 600
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5558024644851685
#
# Current batch: 700
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5152680277824402
#
# Total benign train accuarcy: 81.373
# Total benign train loss: 427.64808627963066
#
# [ Test epoch: 34 ]
#
# Test accuarcy: 29.43
# Test average loss: 0.04745034863948822
# Model Saved!
#
# [ Train epoch: 35 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.5583933591842651
#
# Current batch: 100
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.399405837059021
#
# Current batch: 200
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3719310462474823
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6269209384918213
#
# Current batch: 400
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4010290205478668
#
# Current batch: 500
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6247325539588928
#
# Current batch: 600
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5509035587310791
#
# Current batch: 700
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.372554749250412
#
# Total benign train accuarcy: 81.37
# Total benign train loss: 425.50568544864655
#
# [ Test epoch: 35 ]
#
# Test accuarcy: 22.99
# Test average loss: 0.055611025190353394
# Model Saved!
#
# [ Train epoch: 36 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7603767514228821
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5657097101211548
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5614569783210754
#
# Current batch: 300
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5899187922477722
#
# Current batch: 400
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5370352268218994
#
# Current batch: 500
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4734337627887726
#
# Current batch: 600
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5218563079833984
#
# Current batch: 700
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5907215476036072
#
# Total benign train accuarcy: 81.327
# Total benign train loss: 427.95726603269577
#
# [ Test epoch: 36 ]
#
# Test accuarcy: 11.1
# Test average loss: 0.0721472553730011
# Model Saved!
#
# [ Train epoch: 37 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.45320287346839905
#
# Current batch: 100
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7140865325927734
#
# Current batch: 200
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.37865346670150757
#
# Current batch: 300
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.46451956033706665
#
# Current batch: 400
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.41382232308387756
#
# Current batch: 500
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.37833812832832336
#
# Current batch: 600
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6559855937957764
#
# Current batch: 700
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.46357208490371704
#
# Total benign train accuarcy: 81.746
# Total benign train loss: 417.6337400972843
#
# [ Test epoch: 37 ]
#
# Test accuarcy: 35.38
# Test average loss: 0.03406016416549683
# Model Saved!
#
# [ Train epoch: 38 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3900362551212311
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.472481906414032
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5468834042549133
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.49627062678337097
#
# Current batch: 400
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.34068992733955383
#
# Current batch: 500
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5291206240653992
#
# Current batch: 600
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5774097442626953
#
# Current batch: 700
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5584635734558105
#
# Total benign train accuarcy: 81.468
# Total benign train loss: 425.04355412721634
#
# [ Test epoch: 38 ]
#
# Test accuarcy: 41.13
# Test average loss: 0.02887352612018585
# Model Saved!
#
# [ Train epoch: 39 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.711301326751709
#
# Current batch: 100
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6720759868621826
#
# Current batch: 200
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5348812341690063
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4656270742416382
#
# Current batch: 400
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.465070903301239
#
# Current batch: 500
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.573415219783783
#
# Current batch: 600
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5744243264198303
#
# Current batch: 700
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.6558954119682312
#
# Total benign train accuarcy: 82.018
# Total benign train loss: 411.9757949709892
#
# [ Test epoch: 39 ]
#
# Test accuarcy: 36.72
# Test average loss: 0.03395004014968872
# Model Saved!
#
# [ Train epoch: 40 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6254559755325317
#
# Current batch: 100
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5403047800064087
#
# Current batch: 200
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6763694286346436
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5712828040122986
#
# Current batch: 400
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5323676466941833
#
# Current batch: 500
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5773032307624817
#
# Current batch: 600
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.38607990741729736
#
# Current batch: 700
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6132511496543884
#
# Total benign train accuarcy: 82.09
# Total benign train loss: 412.255491271615
#
# [ Test epoch: 40 ]
#
# Test accuarcy: 17.07
# Test average loss: 0.06665399465560913
# Model Saved!
#
# [ Train epoch: 41 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.41481393575668335
#
# Current batch: 100
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5258768796920776
#
# Current batch: 200
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.33090075850486755
#
# Current batch: 300
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6039292812347412
#
# Current batch: 400
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5192580223083496
#
# Current batch: 500
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.41770732402801514
#
# Current batch: 600
# Current benign train accuracy: 0.875
# Current benign train loss: 0.5775570273399353
#
# Current batch: 700
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.48731234669685364
#
# Total benign train accuarcy: 81.807
# Total benign train loss: 418.526418402791
#
# [ Test epoch: 41 ]
#
# Test accuarcy: 16.6
# Test average loss: 0.07184686536788941
# Model Saved!
#
# [ Train epoch: 42 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5861431360244751
#
# Current batch: 100
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6838957667350769
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4058589041233063
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4241032302379608
#
# Current batch: 400
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6358375549316406
#
# Current batch: 500
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6544977426528931
#
# Current batch: 600
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.49705618619918823
#
# Current batch: 700
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7882598638534546
#
# Total benign train accuarcy: 82.005
# Total benign train loss: 412.4087723493576
#
# [ Test epoch: 42 ]
#
# Test accuarcy: 39.54
# Test average loss: 0.030662938737869263
# Model Saved!
#
# [ Train epoch: 43 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6047556400299072
#
# Current batch: 100
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5726810693740845
#
# Current batch: 200
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6435894966125488
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4763132631778717
#
# Current batch: 400
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.672775149345398
#
# Current batch: 500
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5610100626945496
#
# Current batch: 600
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5163695216178894
#
# Current batch: 700
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.43977776169776917
#
# Total benign train accuarcy: 82.374
# Total benign train loss: 403.2240022420883
#
# [ Test epoch: 43 ]
#
# Test accuarcy: 19.6
# Test average loss: 0.04853974781036377
# Model Saved!
#
# [ Train epoch: 44 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.30666056275367737
#
# Current batch: 100
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6216617822647095
#
# Current batch: 200
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7071152329444885
#
# Current batch: 300
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6238142251968384
#
# Current batch: 400
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4608766734600067
#
# Current batch: 500
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5698606371879578
#
# Current batch: 600
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5085862278938293
#
# Current batch: 700
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5904422402381897
#
# Total benign train accuarcy: 82.307
# Total benign train loss: 408.15793564915657
#
# [ Test epoch: 44 ]
#
# Test accuarcy: 10.61
# Test average loss: 0.12370989379882813
# Model Saved!
#
# [ Train epoch: 45 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5045180916786194
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4766833782196045
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4569467008113861
#
# Current batch: 300
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.692025899887085
#
# Current batch: 400
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6946060657501221
#
# Current batch: 500
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.586089015007019
#
# Current batch: 600
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.35587596893310547
#
# Current batch: 700
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5612319111824036
#
# Total benign train accuarcy: 82.502
# Total benign train loss: 401.0746573060751
#
# [ Test epoch: 45 ]
#
# Test accuarcy: 26.78
# Test average loss: 0.03674859745502472
# Model Saved!
#
# [ Train epoch: 46 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5034274458885193
#
# ...
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1410229504108429
#
# Total benign train accuarcy: 93.189
# Total benign train loss: 155.42527344077826
#
# [ Test epoch: 84 ]
#
# Test accuarcy: 59.98
# Test average loss: 0.021879011857509612
# Model Saved!
#
# [ Train epoch: 85 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.16244655847549438
#
# Current batch: 100
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.27755409479141235
#
# Current batch: 200
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.1521194875240326
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.16470643877983093
#
# Current batch: 400
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.19434422254562378
#
# Current batch: 500
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.28144437074661255
#
# Current batch: 600
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.18261638283729553
#
# Current batch: 700
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.139605313539505
#
# Total benign train accuarcy: 93.316
# Total benign train loss: 152.92298742383718
#
# [ Test epoch: 85 ]
#
# Test accuarcy: 57.04
# Test average loss: 0.018046207225322724
# Model Saved!
#
# [ Train epoch: 86 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.13826270401477814
#
# Current batch: 100
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.14996719360351562
#
# Current batch: 200
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.2277604043483734
#
# Current batch: 300
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.23492813110351562
#
# Current batch: 400
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2705424129962921
#
# Current batch: 500
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.18408754467964172
#
# Current batch: 600
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.14121070504188538
#
# Current batch: 700
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.13535255193710327
#
# Total benign train accuarcy: 93.397
# Total benign train loss: 151.23925384879112
#
# [ Test epoch: 86 ]
#
# Test accuarcy: 47.88
# Test average loss: 0.029288014769554137
# Model Saved!
#
# [ Train epoch: 87 ]
#
# Current batch: 0
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.20524045825004578
#
# Current batch: 100
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2614145576953888
#
# Current batch: 200
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.17958378791809082
#
# Current batch: 300
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.13171423971652985
#
# Current batch: 400
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.27543941140174866
#
# Current batch: 500
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1825447976589203
#
# Current batch: 600
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1766900271177292
#
# Current batch: 700
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.1882893443107605
#
# Total benign train accuarcy: 93.354
# Total benign train loss: 151.62369917333126
#
# [ Test epoch: 87 ]
#
# Test accuarcy: 46.81
# Test average loss: 0.028317375564575194
# Model Saved!
#
# [ Train epoch: 88 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.17534294724464417
#
# Current batch: 100
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.2622145712375641
#
# Current batch: 200
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.25658586621284485
#
# Current batch: 300
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.26788797974586487
#
# Current batch: 400
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2628624439239502
#
# Current batch: 500
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.16087980568408966
#
# Current batch: 600
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1526031345129013
#
# Current batch: 700
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.1936657577753067
#
# Total benign train accuarcy: 93.41
# Total benign train loss: 151.59854295104742
#
# [ Test epoch: 88 ]
#
# Test accuarcy: 45.23
# Test average loss: 0.023988989794254303
# Model Saved!
#
# [ Train epoch: 89 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.17873384058475494
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.17804385721683502
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1432201862335205
#
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.1561705619096756
#
# Current batch: 400
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.17681077122688293
#
# Current batch: 500
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.1743554323911667
#
# Current batch: 600
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.16271154582500458
#
# Current batch: 700
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.1513139307498932
#
# Total benign train accuarcy: 93.44
# Total benign train loss: 150.60697866231203
#
# [ Test epoch: 89 ]
#
# Test accuarcy: 41.41
# Test average loss: 0.03433844485282898
# Model Saved!
#
# [ Train epoch: 90 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.17386744916439056
#
# Current batch: 100
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.13989394903182983
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10288862884044647
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.14995378255844116
#
# Current batch: 400
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11577700078487396
#
# Current batch: 500
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.07959401607513428
#
# Current batch: 600
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10418206453323364
#
# Current batch: 700
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11565245687961578
#
# Total benign train accuarcy: 95.771
# Total benign train loss: 103.63819866999984
#
# [ Test epoch: 90 ]
#
# Test accuarcy: 89.23
# Test average loss: 0.003453777176141739
# Model Saved!
#
# [ Train epoch: 91 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.10310257226228714
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09663306921720505
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09829021990299225
#
# Current batch: 300
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.19697141647338867
#
# Current batch: 400
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.16488172113895416
#
# Current batch: 500
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.19948139786720276
#
# Current batch: 600
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10293497145175934
#
# Current batch: 700
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11309613287448883
#
# Total benign train accuarcy: 96.421
# Total benign train loss: 91.35549561306834
#
# [ Test epoch: 91 ]
#
# Test accuarcy: 89.63
# Test average loss: 0.0034055339813232424
# Model Saved!
#
# [ Train epoch: 92 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10445314645767212
#
# Current batch: 100
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.20302356779575348
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08628569543361664
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.13518090546131134
#
# Current batch: 400
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.10676397383213043
#
# Current batch: 500
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.06434555351734161
#
# Current batch: 600
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11104653775691986
#
# Current batch: 700
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10852280259132385
#
# Total benign train accuarcy: 96.461
# Total benign train loss: 90.6169419027865
#
# [ Test epoch: 92 ]
#
# Test accuarcy: 88.41
# Test average loss: 0.003708016626536846
# Model Saved!
#
# [ Train epoch: 93 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.12049833685159683
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.10291587561368942
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.12365392595529556
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.15129268169403076
#
# Current batch: 400
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07131750136613846
#
# Current batch: 500
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11206740885972977
#
# Current batch: 600
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.13919442892074585
#
# Current batch: 700
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.12183865904808044
#
# Total benign train accuarcy: 96.475
# Total benign train loss: 88.99862386845052
#
# [ Test epoch: 93 ]
#
# Test accuarcy: 89.25
# Test average loss: 0.0034952448084950446
# Model Saved!
#
# [ Train epoch: 94 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11118708550930023
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10258407145738602
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10801751911640167
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10014960914850235
#
# Current batch: 400
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09298952668905258
#
# Current batch: 500
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1099383756518364
#
# Current batch: 600
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11722639203071594
#
# Current batch: 700
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07360335439443588
#
# Total benign train accuarcy: 96.65
# Total benign train loss: 87.62232774868608
#
# [ Test epoch: 94 ]
#
# Test accuarcy: 89.25
# Test average loss: 0.003467724609375
# Model Saved!
#
# [ Train epoch: 95 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.085374616086483
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.1376095563173294
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1114393100142479
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09244125336408615
#
# Current batch: 400
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.13300801813602448
#
# Current batch: 500
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.09409183263778687
#
# Current batch: 600
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09010085463523865
#
# Current batch: 700
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.12310231477022171
#
# Total benign train accuarcy: 96.687
# Total benign train loss: 84.36555929854512
#
# [ Test epoch: 95 ]
#
# Test accuarcy: 89.32
# Test average loss: 0.0034532472923398017
# Model Saved!
#
# [ Train epoch: 96 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.05689585581421852
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11089123785495758
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10848606377840042
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.07105324417352676
#
# Current batch: 400
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.15193232893943787
#
# Current batch: 500
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.12190008908510208
#
# Current batch: 600
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.13637445867061615
#
# Current batch: 700
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.13064485788345337
#
# Total benign train accuarcy: 96.818
# Total benign train loss: 82.9905751273036
#
# [ Test epoch: 96 ]
#
# Test accuarcy: 89.2
# Test average loss: 0.0035012210227549074
# Model Saved!
#
# [ Train epoch: 97 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07886799424886703
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.1017194464802742
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.0798054188489914
#
# Current batch: 300
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.10574294626712799
#
# Current batch: 400
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.10461942106485367
#
# Current batch: 500
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.19995635747909546
#
# Current batch: 600
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.12959575653076172
#
# Current batch: 700
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.1651465743780136
#
# Total benign train accuarcy: 96.816
# Total benign train loss: 83.32036711648107
#
# [ Test epoch: 97 ]
#
# Test accuarcy: 89.31
# Test average loss: 0.003574021568894386
# Model Saved!
#
# [ Train epoch: 98 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07524208724498749
#
# Current batch: 100
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.16853521764278412
#
# Current batch: 200
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.22605407238006592
#
# Current batch: 300
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.08240741491317749
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.07876618206501007
#
# Current batch: 500
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.14715921878814697
#
# Current batch: 600
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10775801539421082
#
# Current batch: 700
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.12159092724323273
#
# Total benign train accuarcy: 96.826
# Total benign train loss: 83.60714459046721
#
# [ Test epoch: 98 ]
#
# Test accuarcy: 89.02
# Test average loss: 0.003711827252060175
# Model Saved!
#
# [ Train epoch: 99 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.09169828146696091
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08345077931880951
#
# Current batch: 200
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.11801937222480774
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.06294137984514236
#
# Current batch: 400
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.11215954273939133
#
# Current batch: 500
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.1270536184310913
#
# Current batch: 600
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09980111569166183
#
# Current batch: 700
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09834180772304535
#
# Total benign train accuarcy: 96.833
# Total benign train loss: 82.5296849347651
#
# [ Test epoch: 99 ]
#
# Test accuarcy: 89.12
# Test average loss: 0.00360664359331131
# Model Saved!
